# %%
# %run "01 Functions.ipynb"

# %% [markdown]
# ## Preprocessing

# %%
count_vif = calculate_vif(X_subset(merged_df, "count", True))
print(count_vif[count_vif["VIF"]>5])

distance_vif = calculate_vif(X_subset(merged_df, "distance", True))
print(distance_vif[distance_vif["VIF"]>5])

# CMCI cols removed due to high VIF
# Out:
#      Feature       VIF
# 7  MallCount  6.132255
# 9   ATMCount  5.884829
#            Feature       VIF
# 6  HospitalHubDist  6.244256
# 7      MallHubDist  5.890305

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### General

# %%
for count_distance in ["count", "distance"]:
    print(f"basic model - {count_distance}", basic_model(merged_df, count_distance, True, True))
    print(f"cv model new - {count_distance}", cv_new(merged_df, count_distance, True, True))
    print(f"cv model - {count_distance}", cv_model2(merged_df, count_distance, True, True))
# Out:
# basic model - count                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.462
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     4446.
# Date:                Fri, 07 Mar 2025   Prob (F-statistic):               0.00
# Time:                        00:07:00   Log-Likelihood:                -57533.
# No. Observations:               51863   AIC:                         1.151e+05
# Df Residuals:                   51852   BIC:                         1.152e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -2.635e-16      0.003  -8.18e-14      1.000      -0.006       0.006
# Num_Bedrooms     -0.2416      0.007    -35.797      0.000      -0.255      -0.228
# Num_Bathrooms     0.0513      0.007      7.532      0.000       0.038       0.065
# Floor_Area        0.7721      0.006    126.243      0.000       0.760       0.784
# Land_Area         0.0423      0.004      9.586      0.000       0.034       0.051
# LRTHubDist       -0.0225      0.004     -6.215      0.000      -0.030      -0.015
# BusCount          0.1624      0.004     36.679      0.000       0.154       0.171
# HospitalCount    -0.0930      0.004    -24.714      0.000      -0.100      -0.086
# MallCount         0.1739      0.006     27.930      0.000       0.162       0.186
# SchoolCount      -0.1144      0.003    -33.281      0.000      -0.121      -0.108
# ATMCount         -0.0496      0.006     -8.048      0.000      -0.062      -0.038
# ==============================================================================
# Omnibus:                    11751.044   Durbin-Watson:                   0.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            26755.977
# Skew:                           1.290   Prob(JB):                         0.00
# Kurtosis:                       5.393   Cond. No.                         5.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  OLS:
#  MSE: 0.6945253764130099
# cv model new - count None
# Average Mean Squared Error (MSE): 0.6945
# Average R-squared (R²): 0.4865
# cv model - count                                               Feature  Average Importance  \
# 11                               local_economy_growth              0.0798
# 2                                       Num_Bathrooms              0.0568
# 5                                          LRTHubDist              0.0381
# 7                                       HospitalCount             -0.0281
# 10                                           ATMCount             -0.0246
# 0                                               const             -0.0046
# 4                                           Land_Area              0.0699
# 8                                           MallCount              0.1332
# 12                                 local_economy_size              0.1101
# 13  presence_of_business_and_professional_organiza...             -0.1119
# 9                                         SchoolCount             -0.1047
# 6                                            BusCount              0.1525
# 1                                        Num_Bedrooms             -0.2292
# 3                                          Floor_Area              0.7680
#
#     Average P>|t|
# 11         0.1608
# 2          0.0376
# 5          0.0202
# 7          0.0171
# 10         0.0002
# 0          0.0000
# 4          0.0000
# 8          0.0000
# 12         0.0000
# 13         0.0000
# 9          0.0000
# 6          0.0000
# 1          0.0000
# 3          0.0000
# basic model - distance                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.457
# Method:                 Least Squares   F-statistic:                     4360.
# Date:                Fri, 07 Mar 2025   Prob (F-statistic):               0.00
# Time:                        00:07:01   Log-Likelihood:                -57766.
# No. Observations:               51863   AIC:                         1.156e+05
# Df Residuals:                   51852   BIC:                         1.157e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const           -2.635e-16      0.003  -8.14e-14      1.000      -0.006       0.006
# Num_Bedrooms       -0.2449      0.007    -36.123      0.000      -0.258      -0.232
# Num_Bathrooms       0.0490      0.007      7.154      0.000       0.036       0.062
# Floor_Area          0.7837      0.006    127.435      0.000       0.772       0.796
# Land_Area           0.0482      0.004     10.727      0.000       0.039       0.057
# LRTHubDist         -0.0381      0.003    -11.127      0.000      -0.045      -0.031
# BusHubDist         -0.1431      0.004    -34.067      0.000      -0.151      -0.135
# HospitalHubDist     0.1501      0.004     41.153      0.000       0.143       0.157
# MallHubDist        -0.1448      0.004    -32.741      0.000      -0.153      -0.136
# SchoolHubDist       0.1099      0.003     32.533      0.000       0.103       0.117
# ATMHubDist         -0.0197      0.004     -4.528      0.000      -0.028      -0.011
# ==============================================================================
# Omnibus:                    11283.983   Durbin-Watson:                   0.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24781.543
# Skew:                           1.257   Prob(JB):                         0.00
# Kurtosis:                       5.269   Cond. No.                         5.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  OLS:
#  MSE: 0.6409503276371508
# cv model new - distance None
# Average Mean Squared Error (MSE): 0.6410
# Average R-squared (R²): 0.4853
# cv model - distance                                               Feature  Average Importance  \
# 5                                          LRTHubDist              0.0219
# 10                                         ATMHubDist             -0.0400
# 0                                               const             -0.0027
# 4                                           Land_Area              0.0719
# 2                                       Num_Bathrooms              0.0599
# 11                               local_economy_growth              0.0351
# 13  presence_of_business_and_professional_organiza...             -0.1081
# 12                                 local_economy_size              0.1191
# 8                                         MallHubDist             -0.1028
# 9                                       SchoolHubDist              0.0993
# 7                                     HospitalHubDist              0.1055
# 6                                          BusHubDist             -0.1435
# 1                                        Num_Bedrooms             -0.2311
# 3                                          Floor_Area              0.7792
#
#     Average P>|t|
# 5          0.0340
# 10         0.0001
# 0          0.0000
# 4          0.0000
# 2          0.0000
# 11         0.0000
# 13         0.0000
# 12         0.0000
# 8          0.0000
# 9          0.0000
# 7          0.0000
# 6          0.0000
# 1          0.0000
# 3          0.0000

# %% [markdown]
# ### Categories - RR & CR

# %%
for count_distance in ["count", "distance"]:
    for category in merged_df["Property Type"].unique().tolist():
        category_df = merged_df[merged_df["Property Type"]==category]
        
        print(category, "- ", count_distance)
        print(cv_model2(category_df, count_distance, True, True))
        print("\n")
# Out:
# RR -  count
# Average Mean Squared Error (MSE): 0.6478
# Average R-squared (R²): 0.5365
#                                               Feature  Average Importance  \
# 2                                       Num_Bathrooms              0.0579
# 0                                               const             -0.0048
# 11                               local_economy_growth              0.0538
# 1                                        Num_Bedrooms             -0.0511
# 10                                           ATMCount             -0.0321
# 7                                       HospitalCount             -0.0390
# 5                                          LRTHubDist              0.0519
# 13  presence_of_business_and_professional_organiza...             -0.1317
# 12                                 local_economy_size              0.0988
# 8                                           MallCount              0.1279
# 6                                            BusCount              0.1423
# 9                                         SchoolCount             -0.1092
# 4                                           Land_Area             -0.3366
# 3                                          Floor_Area              0.9262
#
#     Average P>|t|
# 2          0.1179
# 0          0.0510
# 11         0.0006
# 1          0.0002
# 10         0.0002
# 7          0.0001
# 5          0.0000
# 13         0.0000
# 12         0.0000
# 8          0.0000
# 6          0.0000
# 9          0.0000
# 4          0.0000
# 3          0.0000
#
#
# CR -  count
# Average Mean Squared Error (MSE): 0.5639
# Average R-squared (R²): 0.5429
#                                               Feature  Average Importance  \
# 10                                           ATMCount             -0.0286
# 7                                       HospitalCount              0.0246
# 8                                           MallCount              0.1126
# 1                                        Num_Bedrooms             -0.0000
# 3                                          Floor_Area             -0.0325
# 0                                               const             -0.0101
# 6                                            BusCount              0.0610
# 12                                 local_economy_size              0.1007
# 13  presence_of_business_and_professional_organiza...              0.0441
# 9                                         SchoolCount             -0.0693
# 2                                       Num_Bathrooms             -0.0000
# 11                               local_economy_growth              0.1326
# 5                                          LRTHubDist             -0.2362
# 4                                           Land_Area              0.6436
#
#     Average P>|t|
# 10         0.2498
# 7          0.2341
# 8          0.1952
# 1          0.1556
# 3          0.0706
# 0          0.0560
# 6          0.0352
# 12         0.0161
# 13         0.0020
# 9          0.0011
# 2          0.0000
# 11         0.0000
# 5          0.0000
# 4          0.0000
#
#
# RR -  distance
# Average Mean Squared Error (MSE): 0.6015
# Average R-squared (R²): 0.5325
#                                               Feature  Average Importance  \
# 0                                               const             -0.0029
# 10                                         ATMHubDist              0.0027
# 13  presence_of_business_and_professional_organiza...             -0.1289
# 5                                          LRTHubDist              0.0344
# 2                                       Num_Bathrooms              0.0634
# 11                               local_economy_growth              0.0139
# 1                                        Num_Bedrooms             -0.0532
# 12                                 local_economy_size              0.1057
# 9                                       SchoolHubDist              0.0812
# 8                                         MallHubDist             -0.1108
# 6                                          BusHubDist             -0.1418
# 7                                     HospitalHubDist              0.1173
# 4                                           Land_Area             -0.3388
# 3                                          Floor_Area              0.9348
#
#     Average P>|t|
# 0          0.0804
# 10         0.0328
# 13         0.0010
# 5          0.0004
# 2          0.0000
# 11         0.0000
# 1          0.0000
# 12         0.0000
# 9          0.0000
# 8          0.0000
# 6          0.0000
# 7          0.0000
# 4          0.0000
# 3          0.0000
#
#
# CR -  distance
# Average Mean Squared Error (MSE): 0.5749
# Average R-squared (R²): 0.5487
#                                               Feature  Average Importance  \
# 3                                          Floor_Area             -0.0085
# 13  presence_of_business_and_professional_organiza...              0.0332
# 0                                               const             -0.0164
# 6                                          BusHubDist             -0.0576
# 9                                       SchoolHubDist              0.0629
# 7                                     HospitalHubDist              0.0788
# 2                                       Num_Bathrooms              0.0000
# 12                                 local_economy_size              0.0793
# 11                               local_economy_growth              0.1081
# 8                                         MallHubDist             -0.0938
# 10                                         ATMHubDist             -0.1085
# 5                                          LRTHubDist             -0.2159
# 1                                        Num_Bedrooms              0.0000
# 4                                           Land_Area              0.6359
#
#     Average P>|t|
# 3          0.1941
# 13         0.0554
# 0          0.0530
# 6          0.0144
# 9          0.0092
# 7          0.0067
# 2          0.0020
# 12         0.0003
# 11         0.0000
# 8          0.0000
# 10         0.0000
# 5          0.0000
# 1          0.0000
# 4          0.0000

# %% [markdown]
# ### Categories

# %%
for count_distance in ["count", "distance"]:
    for category in merged_df["Category"].unique().tolist():
        category_df = merged_df[merged_df["Category"]==category]
        
        print(category)
        print(cv_model2(category_df, count_distance, True, True))
        print("\n")
# Out:
# house
# Average Mean Squared Error (MSE): 0.3197
# Average R-squared (R²): 0.7338
#                                               Feature  Average Importance  \
# 13  presence_of_business_and_professional_organiza...              0.0160
# 1                                        Num_Bedrooms             -0.0262
# 0                                               const              0.0077
# 5                                          LRTHubDist             -0.0458
# 12                                 local_economy_size              0.0253
# 8                                           MallCount              0.0452
# 7                                       HospitalCount             -0.0218
# 2                                       Num_Bathrooms              0.0502
# 9                                         SchoolCount             -0.0464
# 11                               local_economy_growth              0.0617
# 10                                           ATMCount              0.0981
# 6                                            BusCount              0.1355
# 4                                           Land_Area              0.2335
# 3                                          Floor_Area              0.6194
#
#     Average P>|t|
# 13         0.2149
# 1          0.0816
# 0          0.0281
# 5          0.0031
# 12         0.0018
# 8          0.0005
# 7          0.0003
# 2          0.0000
# 9          0.0000
# 11         0.0000
# 10         0.0000
# 6          0.0000
# 4          0.0000
# 3          0.0000
#
#
# condo
# Average Mean Squared Error (MSE): 0.3703
# Average R-squared (R²): 0.7036
#                                               Feature  Average Importance  \
# 10                                           ATMCount             -0.0348
# 5                                          LRTHubDist              0.0509
# 8                                           MallCount              0.0165
# 12                                 local_economy_size              0.0364
# 11                               local_economy_growth              0.0258
# 0                                               const             -0.0043
# 7                                       HospitalCount             -0.0465
# 6                                            BusCount              0.0922
# 4                                           Land_Area              0.0000
# 9                                         SchoolCount             -0.0550
# 13  presence_of_business_and_professional_organiza...             -0.1145
# 1                                        Num_Bedrooms             -0.1416
# 2                                       Num_Bathrooms              0.1054
# 3                                          Floor_Area              0.8078
#
#     Average P>|t|
# 10         0.2158
# 5          0.1978
# 8          0.1386
# 12         0.1019
# 11         0.1015
# 0          0.0036
# 7          0.0002
# 6          0.0000
# 4          0.0000
# 9          0.0000
# 13         0.0000
# 1          0.0000
# 2          0.0000
# 3          0.0000
#
#
# land
# Average Mean Squared Error (MSE): 0.6429
# Average R-squared (R²): 0.5482
#                                               Feature  Average Importance  \
# 7                                       HospitalCount              0.0113
# 8                                           MallCount              0.0347
# 6                                            BusCount              0.0489
# 13  presence_of_business_and_professional_organiza...              0.0418
# 2                                       Num_Bathrooms             -0.0000
# 3                                          Floor_Area              0.0000
# 9                                         SchoolCount             -0.0194
# 12                                 local_economy_size              0.0809
# 0                                               const              0.0002
# 10                                           ATMCount              0.0917
# 1                                        Num_Bedrooms              0.0000
# 11                               local_economy_growth              0.1715
# 5                                          LRTHubDist             -0.2837
# 4                                           Land_Area              0.5179
#
#     Average P>|t|
# 7          0.2781
# 8          0.2384
# 6          0.1981
# 13         0.1781
# 2          0.1699
# 3          0.0207
# 9          0.0195
# 12         0.0105
# 0          0.0024
# 10         0.0000
# 1          0.0000
# 11         0.0000
# 5          0.0000
# 4          0.0000
#
#
# commercial
# Average Mean Squared Error (MSE): 0.5130
# Average R-squared (R²): 0.5430
#                                               Feature  Average Importance  \
# 0                                               const             -0.0044
# 13  presence_of_business_and_professional_organiza...              0.0069
# 7                                       HospitalCount              0.0151
# 5                                          LRTHubDist             -0.0244
# 6                                            BusCount              0.0208
# 10                                           ATMCount             -0.0976
# 2                                       Num_Bathrooms              0.0000
# 1                                        Num_Bedrooms             -0.0000
# 8                                           MallCount              0.1822
# 9                                         SchoolCount             -0.0691
# 11                               local_economy_growth              0.0940
# 12                                 local_economy_size              0.1465
# 4                                           Land_Area              0.2851
# 3                                          Floor_Area              0.5696
#
#     Average P>|t|
# 0          0.5332
# 13         0.4229
# 7          0.3952
# 5          0.3677
# 6          0.3348
# 10         0.0991
# 2          0.0580
# 1          0.0148
# 8          0.0057
# 9          0.0037
# 11         0.0024
# 12         0.0001
# 4          0.0000
# 3          0.0000
#
#
# apartment
# Average Mean Squared Error (MSE): 0.9947
# Average R-squared (R²): 0.4256
#                                               Feature  Average Importance  \
# 4                                           Land_Area              0.0000
# 7                                       HospitalCount              0.0411
# 2                                       Num_Bathrooms             -0.0376
# 5                                          LRTHubDist              0.0751
# 0                                               const             -0.0013
# 9                                         SchoolCount             -0.0707
# 10                                           ATMCount             -0.1981
# 13  presence_of_business_and_professional_organiza...             -0.1606
# 6                                            BusCount              0.1326
# 8                                           MallCount              0.1916
# 12                                 local_economy_size              0.2100
# 11                               local_economy_growth              0.2855
# 1                                        Num_Bedrooms              0.3097
# 3                                          Floor_Area              0.3389
#
#     Average P>|t|
# 4          0.7678
# 7          0.5478
# 2          0.5247
# 5          0.3599
# 0          0.2780
# 9          0.2243
# 10         0.2206
# 13         0.1639
# 6          0.1341
# 8          0.0827
# 12         0.0205
# 11         0.0092
# 1          0.0000
# 3          0.0000
#
#
# house
# Average Mean Squared Error (MSE): 0.3552
# Average R-squared (R²): 0.7163
#                                               Feature  Average Importance  \
# 1                                        Num_Bedrooms             -0.0332
# 0                                               const              0.0090
# 10                                         ATMHubDist             -0.0313
# 13  presence_of_business_and_professional_organiza...              0.0226
# 11                               local_economy_growth              0.0273
# 12                                 local_economy_size              0.0570
# 9                                       SchoolHubDist              0.0502
# 2                                       Num_Bathrooms              0.0636
# 7                                     HospitalHubDist              0.0671
# 8                                         MallHubDist             -0.0628
# 5                                          LRTHubDist             -0.0718
# 6                                          BusHubDist             -0.1237
# 4                                           Land_Area              0.1955
# 3                                          Floor_Area              0.6526
#
#     Average P>|t|
# 1          0.1889
# 0          0.1604
# 10         0.0516
# 13         0.0426
# 11         0.0008
# 12         0.0002
# 9          0.0000
# 2          0.0000
# 7          0.0000
# 8          0.0000
# 5          0.0000
# 6          0.0000
# 4          0.0000
# 3          0.0000
#
#
# condo
# Average Mean Squared Error (MSE): 0.3675
# Average R-squared (R²): 0.7029
#                                               Feature  Average Importance  \
# 10                                         ATMHubDist              0.0223
# 6                                          BusHubDist             -0.0333
# 9                                       SchoolHubDist              0.0155
# 12                                 local_economy_size              0.0110
# 8                                         MallHubDist             -0.0441
# 0                                               const             -0.0013
# 11                               local_economy_growth              0.0076
# 5                                          LRTHubDist              0.0201
# 4                                           Land_Area             -0.0000
# 13  presence_of_business_and_professional_organiza...             -0.1247
# 7                                     HospitalHubDist              0.0761
# 1                                        Num_Bedrooms             -0.1387
# 2                                       Num_Bathrooms              0.1033
# 3                                          Floor_Area              0.8103
#
#     Average P>|t|
# 10         0.2346
# 6          0.1327
# 9          0.1181
# 12         0.0690
# 8          0.0688
# 0          0.0624
# 11         0.0000
# 5          0.0000
# 4          0.0000
# 13         0.0000
# 7          0.0000
# 1          0.0000
# 2          0.0000
# 3          0.0000
#
#
# land
# Average Mean Squared Error (MSE): 0.6574
# Average R-squared (R²): 0.5357
#                                               Feature  Average Importance  \
# 9                                       SchoolHubDist              0.0125
# 2                                       Num_Bathrooms              0.0000
# 8                                         MallHubDist             -0.0365
# 7                                     HospitalHubDist              0.0428
# 10                                         ATMHubDist             -0.0393
# 13  presence_of_business_and_professional_organiza...              0.0423
# 6                                          BusHubDist             -0.0464
# 12                                 local_economy_size              0.1191
# 0                                               const             -0.0030
# 1                                        Num_Bedrooms              0.0000
# 3                                          Floor_Area             -0.0000
# 11                               local_economy_growth              0.1942
# 5                                          LRTHubDist             -0.2734
# 4                                           Land_Area              0.5121
#
#     Average P>|t|
# 9          0.3246
# 2          0.1925
# 8          0.1457
# 7          0.1335
# 10         0.0938
# 13         0.0901
# 6          0.0707
# 12         0.0083
# 0          0.0049
# 1          0.0000
# 3          0.0000
# 11         0.0000
# 5          0.0000
# 4          0.0000
#
#
# commercial
# Average Mean Squared Error (MSE): 0.5070
# Average R-squared (R²): 0.5465
#                                               Feature  Average Importance  \
# 13  presence_of_business_and_professional_organiza...              0.0195
# 6                                          BusHubDist              0.0224
# 0                                               const             -0.0016
# 1                                        Num_Bedrooms             -0.0000
# 10                                         ATMHubDist             -0.0378
# 5                                          LRTHubDist             -0.0404
# 7                                     HospitalHubDist              0.0558
# 11                               local_economy_growth              0.0701
# 9                                       SchoolHubDist              0.0681
# 8                                         MallHubDist             -0.0893
# 12                                 local_economy_size              0.1155
# 2                                       Num_Bathrooms             -0.0000
# 4                                           Land_Area              0.2789
# 3                                          Floor_Area              0.5666
#
#     Average P>|t|
# 13         0.5818
# 6          0.3653
# 0          0.3095
# 1          0.2150
# 10         0.1834
# 5          0.1363
# 7          0.0673
# 11         0.0342
# 9          0.0015
# 8          0.0009
# 12         0.0004
# 2          0.0000
# 4          0.0000
# 3          0.0000
#
#
# apartment
# Average Mean Squared Error (MSE): 1.0423
# Average R-squared (R²): 0.4446
#                                               Feature  Average Importance  \
# 7                                     HospitalHubDist              0.0308
# 10                                         ATMHubDist             -0.0019
# 2                                       Num_Bathrooms             -0.0364
# 5                                          LRTHubDist              0.0579
# 8                                         MallHubDist             -0.0140
# 0                                               const             -0.0007
# 4                                           Land_Area              0.0000
# 13  presence_of_business_and_professional_organiza...             -0.1231
# 9                                       SchoolHubDist              0.1527
# 11                               local_economy_growth              0.1965
# 12                                 local_economy_size              0.1539
# 6                                          BusHubDist             -0.1712
# 1                                        Num_Bedrooms              0.3124
# 3                                          Floor_Area              0.3366
#
#     Average P>|t|
# 7          0.5000
# 10         0.4760
# 2          0.4563
# 5          0.4561
# 8          0.4005
# 0          0.3671
# 4          0.2356
# 13         0.2340
# 9          0.1871
# 11         0.1119
# 12         0.0714
# 6          0.0303
# 1          0.0000
# 3          0.0000

# %% [markdown]
# # END
