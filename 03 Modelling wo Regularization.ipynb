# %%
# %run "00 Functions.ipynb"

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Zonal Values

# %%
RR_CR_dct = {"condo": "RR", "house": "RR", "apartment":"RR", "commercial":"CR", "land":"CR"}
qgis_df["Property Type"] = qgis_df["Category"].map(RR_CR_dct)

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Functions

# %%
dfw = process_data(qgis_df, False, False)
dfx = process_data(qgis_df, True, True)
dfy = process_data(qgis_df, False, True)
dfz = process_data(qgis_df, True, False)
print(len(dfw), len(dfx), len(dfy), len(dfz))
# Out:
# 49032 25060 49032 25060

# %% [markdown]
# ### General

# %%
for count_distance in ["count", "distance"]:
    print(f"basic model - {count_distance}", basic_model(general_df, count_distance, True, True))
    print(f"iterated model - {count_distance}", iterated_model(general_df, count_distance, 10, True, True))
    print(f"cv model - {count_distance}", cv_model2(general_df, count_distance, True, True))
# Out:
# basic model - count                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.549
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     3386.
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):               0.00
# Time:                        00:08:13   Log-Likelihood:                 13525.
# No. Observations:               25060   AIC:                        -2.703e+04
# Df Residuals:                   25050   BIC:                        -2.695e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.1009      0.004     26.370      0.000       0.093       0.108
# LRTHubDist        0.0187      0.006      3.373      0.001       0.008       0.030
# Num_Bedrooms     -0.2114      0.011    -18.608      0.000      -0.234      -0.189
# Num_Bathrooms     0.0662      0.010      6.669      0.000       0.047       0.086
# Floor_Area        1.0126      0.010    104.838      0.000       0.994       1.032
# Land_Area        -0.1263      0.006    -20.743      0.000      -0.138      -0.114
# BusCount          0.0771      0.005     16.426      0.000       0.068       0.086
# SchoolCount      -0.0224      0.004     -5.184      0.000      -0.031      -0.014
# MallCount         0.1003      0.004     26.187      0.000       0.093       0.108
# HospitalCount    -0.0614      0.003    -19.423      0.000      -0.068      -0.055
# ==============================================================================
# Omnibus:                     6045.375   Durbin-Watson:                   1.177
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16662.899
# Skew:                           1.283   Prob(JB):                         0.00
# Kurtosis:                       6.062   Cond. No.                         20.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Average Mean Squared Error (MSE) across iterations: 0.02
# R-squared (R²) on Test Data: across iterations: 0.55
# iterated model - count                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.546
# Model:                            OLS   Adj. R-squared:                  0.546
# Method:                 Least Squares   F-statistic:                     2409.
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):               0.00
# Time:                        00:08:14   Log-Likelihood:                 10774.
# No. Observations:               20048   AIC:                        -2.153e+04
# Df Residuals:                   20037   BIC:                        -2.144e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1052      0.004     23.526      0.000       0.096       0.114
# LRTHubDist              0.0149      0.006      2.356      0.018       0.002       0.027
# Num_Bedrooms           -0.2103      0.013    -16.560      0.000      -0.235      -0.185
# Num_Bathrooms           0.0705      0.011      6.330      0.000       0.049       0.092
# Floor_Area              1.0050      0.011     92.327      0.000       0.984       1.026
# Land_Area              -0.1196      0.007    -17.300      0.000      -0.133      -0.106
# BusCount                0.0740      0.005     14.007      0.000       0.064       0.084
# SchoolCount            -0.0244      0.005     -5.052      0.000      -0.034      -0.015
# MallCount               0.1025      0.004     23.866      0.000       0.094       0.111
# HospitalCount          -0.0596      0.004    -16.885      0.000      -0.067      -0.053
# Matched_Zonal_Value    -0.0625      0.016     -3.900      0.000      -0.094      -0.031
# ==============================================================================
# Omnibus:                     4957.375   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14085.833
# Skew:                           1.302   Prob(JB):                         0.00
# Kurtosis:                       6.175   Cond. No.                         22.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Average Mean Squared Error (MSE): 0.0254
# Average R-squared (R²): 0.5511
# cv model - count                 Feature  Average Importance  Average P>|t|
# 7           SchoolCount             -0.0269         0.1624
# 1            LRTHubDist              0.0084         0.0494
# 5             Land_Area             -0.1125         0.0081
# 6              BusCount              0.0803         0.0015
# 10  Matched_Zonal_Value             -0.0381         0.0000
# 3         Num_Bathrooms              0.0751         0.0000
# 8             MallCount              0.0975         0.0000
# 9         HospitalCount             -0.0642         0.0000
# 2          Num_Bedrooms             -0.2017         0.0000
# 0                 const              0.1024         0.0000
# 4            Floor_Area              0.9995         0.0000
# basic model - distance                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     3486.
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):               0.00
# Time:                        00:08:14   Log-Likelihood:                 13727.
# No. Observations:               25060   AIC:                        -2.743e+04
# Df Residuals:                   25050   BIC:                        -2.735e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0939      0.004     25.845      0.000       0.087       0.101
# LRTHubDist         -0.0039      0.005     -0.742      0.458      -0.014       0.006
# Num_Bedrooms       -0.1987      0.011    -17.604      0.000      -0.221      -0.177
# Num_Bathrooms       0.0722      0.010      7.318      0.000       0.053       0.091
# Floor_Area          1.0313      0.010    108.267      0.000       1.013       1.050
# Land_Area          -0.1503      0.006    -25.480      0.000      -0.162      -0.139
# BusHubDist         -0.0826      0.004    -19.266      0.000      -0.091      -0.074
# SchoolHubDist       0.0232      0.004      5.552      0.000       0.015       0.031
# MallHubDist        -0.0806      0.005    -17.691      0.000      -0.090      -0.072
# HospitalHubDist     0.1659      0.004     38.207      0.000       0.157       0.174
# ==============================================================================
# Omnibus:                     5563.357   Durbin-Watson:                   1.203
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14945.815
# Skew:                           1.192   Prob(JB):                         0.00
# Kurtosis:                       5.938   Cond. No.                         21.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Average Mean Squared Error (MSE) across iterations: 0.02
# R-squared (R²) on Test Data: across iterations: 0.56
# iterated model - distance                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                     2472.
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):               0.00
# Time:                        00:08:14   Log-Likelihood:                 10915.
# No. Observations:               20048   AIC:                        -2.181e+04
# Df Residuals:                   20037   BIC:                        -2.172e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1002      0.004     24.247      0.000       0.092       0.108
# LRTHubDist             -0.0092      0.006     -1.551      0.121      -0.021       0.002
# Num_Bedrooms           -0.1994      0.013    -15.788      0.000      -0.224      -0.175
# Num_Bathrooms           0.0769      0.011      6.955      0.000       0.055       0.099
# Floor_Area              1.0214      0.011     95.012      0.000       1.000       1.043
# Land_Area              -0.1410      0.007    -20.973      0.000      -0.154      -0.128
# BusHubDist             -0.0789      0.005    -16.433      0.000      -0.088      -0.070
# SchoolHubDist           0.0238      0.005      5.092      0.000       0.015       0.033
# MallHubDist            -0.0820      0.005    -16.033      0.000      -0.092      -0.072
# HospitalHubDist         0.1641      0.005     33.547      0.000       0.154       0.174
# Matched_Zonal_Value    -0.0991      0.016     -6.227      0.000      -0.130      -0.068
# ==============================================================================
# Omnibus:                     4628.363   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12932.327
# Skew:                           1.222   Prob(JB):                         0.00
# Kurtosis:                       6.083   Cond. No.                         22.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Average Mean Squared Error (MSE): 0.0234
# Average R-squared (R²): 0.5562
# cv model - distance                 Feature  Average Importance  Average P>|t|
# 1            LRTHubDist             -0.0155         0.0138
# 7         SchoolHubDist              0.0277         0.0004
# 3         Num_Bathrooms              0.0790         0.0000
# 10  Matched_Zonal_Value             -0.0734         0.0000
# 5             Land_Area             -0.1369         0.0000
# 8           MallHubDist             -0.0777         0.0000
# 6            BusHubDist             -0.0819         0.0000
# 2          Num_Bedrooms             -0.1911         0.0000
# 0                 const              0.0946         0.0000
# 9       HospitalHubDist              0.1668         0.0000
# 4            Floor_Area              1.0169         0.0000

# %% [markdown]
# ### Categories - RR & CR

# %%
for count_distance in ["count", "distance"]:
    for category in general_df["Property Type"].unique().tolist():
        category_df = general_df[general_df["Property Type"]==category]
        
        print(category, "- ", count_distance)
        print(basic_model2(category_df, count_distance, True, True))
        print("\n")
# Out:
# RR -  count
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.544
# Method:                 Least Squares   F-statistic:                     2950.
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):               0.00
# Time:                        00:08:15   Log-Likelihood:                 13128.
# No. Observations:               24714   AIC:                        -2.623e+04
# Df Residuals:                   24703   BIC:                        -2.614e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0998      0.004     24.448      0.000       0.092       0.108
# LRTHubDist              0.0110      0.005      2.052      0.040       0.000       0.021
# Num_Bedrooms           -0.1603      0.010    -15.976      0.000      -0.180      -0.141
# Num_Bathrooms           0.0769      0.010      7.458      0.000       0.057       0.097
# Floor_Area              1.0503      0.010    103.879      0.000       1.031       1.070
# Land_Area              -0.1671      0.006    -26.020      0.000      -0.180      -0.155
# BusCount                0.0835      0.005     17.297      0.000       0.074       0.093
# SchoolCount            -0.0137      0.004     -3.098      0.002      -0.022      -0.005
# MallCount               0.0978      0.004     23.540      0.000       0.090       0.106
# HospitalCount          -0.0718      0.004    -19.513      0.000      -0.079      -0.065
# Matched_Zonal_Value    -0.0108      0.005     -2.076      0.038      -0.021      -0.001
# ==============================================================================
# Omnibus:                     5997.911   Durbin-Watson:                   1.200
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16283.726
# Skew:                           1.297   Prob(JB):                         0.00
# Kurtosis:                       6.014   Cond. No.                         19.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# CR -  count
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     129.8
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):          1.14e-114
# Time:                        00:08:15   Log-Likelihood:                 278.46
# No. Observations:                1523   AIC:                            -544.9
# Df Residuals:                    1517   BIC:                            -513.0
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.2690      0.018     14.551      0.000       0.233       0.305
# LRTHubDist             -0.1943      0.022     -8.684      0.000      -0.238      -0.150
# Num_Bedrooms        -3.959e-15   2.79e-16    -14.175      0.000   -4.51e-15   -3.41e-15
# Num_Bathrooms       -9.254e-16   6.63e-17    -13.948      0.000   -1.06e-15   -7.95e-16
# Floor_Area           1.269e-15   9.59e-17     13.236      0.000    1.08e-15    1.46e-15
# Land_Area               0.4592      0.031     14.598      0.000       0.397       0.521
# BusCount                0.3322      0.023     14.755      0.000       0.288       0.376
# SchoolCount            -0.0610      0.023     -2.612      0.009      -0.107      -0.015
# MallCount                    0          0        nan        nan           0           0
# HospitalCount                0          0        nan        nan           0           0
# Matched_Zonal_Value    -0.2580      0.059     -4.408      0.000      -0.373      -0.143
# ==============================================================================
# Omnibus:                      218.905   Durbin-Watson:                   1.446
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              340.127
# Skew:                           0.985   Prob(JB):                     1.39e-74
# Kurtosis:                       4.216   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# RR -  distance
# c:\Users\Leibniz\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1918: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.548
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     2994.
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):               0.00
# Time:                        00:08:15   Log-Likelihood:                 13229.
# No. Observations:               24714   AIC:                        -2.644e+04
# Df Residuals:                   24703   BIC:                        -2.635e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1086      0.004     28.987      0.000       0.101       0.116
# LRTHubDist             -0.0221      0.005     -4.322      0.000      -0.032      -0.012
# Num_Bedrooms           -0.1527      0.010    -15.260      0.000      -0.172      -0.133
# Num_Bathrooms           0.0827      0.010      8.055      0.000       0.063       0.103
# Floor_Area              1.0700      0.010    107.018      0.000       1.050       1.090
# Land_Area              -0.1981      0.006    -31.622      0.000      -0.210      -0.186
# BusHubDist             -0.0738      0.004    -16.821      0.000      -0.082      -0.065
# SchoolHubDist           0.0110      0.005      2.436      0.015       0.002       0.020
# MallHubDist            -0.0877      0.005    -19.440      0.000      -0.097      -0.079
# HospitalHubDist         0.1594      0.004     36.621      0.000       0.151       0.168
# Matched_Zonal_Value    -0.0194      0.005     -3.783      0.000      -0.029      -0.009
# ==============================================================================
# Omnibus:                     5334.579   Durbin-Watson:                   1.201
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13613.721
# Skew:                           1.180   Prob(JB):                         0.00
# Kurtosis:                       5.766   Cond. No.                         20.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# CR -  distance
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.315
# Method:                 Least Squares   F-statistic:                     100.9
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):          3.64e-121
# Time:                        00:08:15   Log-Likelihood:                 298.54
# No. Observations:                1523   AIC:                            -581.1
# Df Residuals:                    1515   BIC:                            -538.5
# Df Model:                           7
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.3834      0.019     20.294      0.000       0.346       0.420
# LRTHubDist             -0.1617      0.028     -5.757      0.000      -0.217      -0.107
# Num_Bedrooms        -1.726e-16   2.42e-17     -7.146      0.000    -2.2e-16   -1.25e-16
# Num_Bathrooms        2.433e-17   1.88e-17      1.292      0.197   -1.26e-17    6.13e-17
# Floor_Area          -1.474e-16   1.44e-17    -10.238      0.000   -1.76e-16   -1.19e-16
# Land_Area               0.4974      0.032     15.600      0.000       0.435       0.560
# BusHubDist             -0.3917      0.032    -12.150      0.000      -0.455      -0.328
# SchoolHubDist           0.1696      0.025      6.734      0.000       0.120       0.219
# MallHubDist            -0.0089      0.035     -0.253      0.800      -0.078       0.060
# HospitalHubDist        -0.1006      0.030     -3.406      0.001      -0.159      -0.043
# Matched_Zonal_Value    -0.2437      0.058     -4.205      0.000      -0.357      -0.130
# ==============================================================================
# Omnibus:                      246.917   Durbin-Watson:                   1.483
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              404.455
# Skew:                           1.064   Prob(JB):                     1.49e-88
# Kurtosis:                       4.357   Cond. No.                     1.47e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.51e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
for count_distance in ["count", "distance"]:
    for category in general_df["Property Type"].unique().tolist():
        category_df = general_df[general_df["Property Type"]==category]
        
        print(category, "- ", count_distance)
        print(cv_model2(category_df, count_distance, True, True))
        print("\n")
# Out:
# RR -  count
# Average Mean Squared Error (MSE): 0.0262
# Average R-squared (R²): 0.5480
#                 Feature  Average Importance  Average P>|t|
# 7           SchoolCount             -0.0142         0.0871
# 10  Matched_Zonal_Value             -0.0070         0.0169
# 1            LRTHubDist              0.0032         0.0076
# 3         Num_Bathrooms              0.0856         0.0000
# 6              BusCount              0.0878         0.0000
# 5             Land_Area             -0.1579         0.0000
# 2          Num_Bedrooms             -0.1550         0.0000
# 8             MallCount              0.0919         0.0000
# 9         HospitalCount             -0.0781         0.0000
# 0                 const              0.0971         0.0000
# 4            Floor_Area              1.0472         0.0000
#
#
# CR -  count
# Average Mean Squared Error (MSE): 0.0501
# Average R-squared (R²): 0.3025
#                 Feature  Average Importance  Average P>|t|
# 7           SchoolCount             -0.0520         0.1537
# 2          Num_Bedrooms             -0.0000         0.1136
# 4            Floor_Area             -0.0000         0.1053
# 3         Num_Bathrooms             -0.0000         0.0155
# 10  Matched_Zonal_Value             -0.2493         0.0009
# 1            LRTHubDist             -0.1918         0.0000
# 6              BusCount              0.3237         0.0000
# 5             Land_Area              0.4643         0.0000
# 0                 const              0.2655         0.0000
# 8             MallCount              0.0000            NaN
# 9         HospitalCount              0.0000            NaN
#
#
# RR -  distance
# Average Mean Squared Error (MSE): 0.0249
# Average R-squared (R²): 0.5503
#                 Feature  Average Importance  Average P>|t|
# 7         SchoolHubDist              0.0148         0.1724
# 10  Matched_Zonal_Value             -0.0148         0.0002
# 1            LRTHubDist             -0.0269         0.0000
# 3         Num_Bathrooms              0.0897         0.0000
# 8           MallHubDist             -0.0855         0.0000
# 2          Num_Bedrooms             -0.1496         0.0000
# 6            BusHubDist             -0.0737         0.0000
# 5             Land_Area             -0.1900         0.0000
# 0                 const              0.1045         0.0000
# 9       HospitalHubDist              0.1564         0.0000
# 4            Floor_Area              1.0642         0.0000
#
#
# CR -  distance
# Average Mean Squared Error (MSE): 0.0498
# Average R-squared (R²): 0.3229
#                 Feature  Average Importance  Average P>|t|
# 8           MallHubDist             -0.0122         0.3720
# 3         Num_Bathrooms             -0.0000         0.1895
# 9       HospitalHubDist             -0.0870         0.1738
# 4            Floor_Area              0.0000         0.1206
# 2          Num_Bedrooms              0.0000         0.0462
# 10  Matched_Zonal_Value             -0.2475         0.0006
# 1            LRTHubDist             -0.1628         0.0000
# 7         SchoolHubDist              0.1558         0.0000
# 6            BusHubDist             -0.3918         0.0000
# 5             Land_Area              0.5083         0.0000
# 0                 const              0.3843         0.0000

# %% [markdown]
# ### Categories

# %%
for count_distance in ["count", "distance"]:
    for category in general_df["Category"].unique().tolist():
        category_df = general_df[general_df["Category"]==category]
        
        print(category)
        print(basic_model2(category_df, count_distance, True, True))
        print("\n")
# Out:
# house
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.710
# Model:                            OLS   Adj. R-squared:                  0.710
# Method:                 Least Squares   F-statistic:                     3446.
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):               0.00
# Time:                        00:08:16   Log-Likelihood:                 11316.
# No. Observations:               14067   AIC:                        -2.261e+04
# Df Residuals:                   14056   BIC:                        -2.253e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0196      0.004      4.728      0.000       0.011       0.028
# LRTHubDist             -0.1182      0.005    -21.675      0.000      -0.129      -0.107
# Num_Bedrooms           -0.0048      0.005     -0.987      0.324      -0.014       0.005
# Num_Bathrooms           0.0154      0.005      3.001      0.003       0.005       0.026
# Floor_Area              0.8479      0.009     99.111      0.000       0.831       0.865
# Land_Area               0.1899      0.006     32.541      0.000       0.179       0.201
# BusCount                0.1269      0.004     30.230      0.000       0.119       0.135
# SchoolCount             0.0205      0.005      3.782      0.000       0.010       0.031
# MallCount              -0.0107      0.004     -2.725      0.006      -0.018      -0.003
# HospitalCount          -0.0531      0.004    -14.194      0.000      -0.060      -0.046
# Matched_Zonal_Value    -0.0988      0.005    -20.107      0.000      -0.108      -0.089
# ==============================================================================
# Omnibus:                     2978.594   Durbin-Watson:                   1.449
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12440.550
# Skew:                           0.991   Prob(JB):                         0.00
# Kurtosis:                       7.159   Cond. No.                         16.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# condo
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.657
# Model:                            OLS   Adj. R-squared:                  0.657
# Method:                 Least Squares   F-statistic:                     2555.
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):               0.00
# Time:                        00:08:17   Log-Likelihood:                 7363.8
# No. Observations:               12009   AIC:                        -1.471e+04
# Df Residuals:                   11999   BIC:                        -1.463e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0515      0.007      7.777      0.000       0.039       0.064
# LRTHubDist             -0.0333      0.008     -4.245      0.000      -0.049      -0.018
# Num_Bedrooms           -0.3019      0.008    -36.345      0.000      -0.318      -0.286
# Num_Bathrooms           0.1395      0.007     19.660      0.000       0.126       0.153
# Floor_Area              1.0879      0.009    118.366      0.000       1.070       1.106
# Land_Area            2.014e-15   4.71e-17     42.741      0.000    1.92e-15    2.11e-15
# BusCount               -0.0140      0.008     -1.837      0.066      -0.029       0.001
# SchoolCount             0.0011      0.006      0.185      0.853      -0.011       0.013
# MallCount               0.0302      0.006      5.456      0.000       0.019       0.041
# HospitalCount          -0.0091      0.006     -1.575      0.115      -0.020       0.002
# Matched_Zonal_Value    -0.0456      0.008     -5.860      0.000      -0.061      -0.030
# ==============================================================================
# Omnibus:                      679.693   Durbin-Watson:                   1.444
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2866.096
# Skew:                           0.032   Prob(JB):                         0.00
# Kurtosis:                       5.392   Cond. No.                     1.08e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.24e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# apartment
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.395
# Model:                            OLS   Adj. R-squared:                  0.347
# Method:                 Least Squares   F-statistic:                     8.131
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):           3.27e-09
# Time:                        00:08:17   Log-Likelihood:                 33.844
# No. Observations:                 122   AIC:                            -47.69
# Df Residuals:                     112   BIC:                            -19.65
# Df Model:                           9
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0967      0.074      1.302      0.195      -0.050       0.244
# LRTHubDist             -0.0738      0.086     -0.859      0.392      -0.244       0.096
# Num_Bedrooms            0.4377      0.099      4.424      0.000       0.242       0.634
# Num_Bathrooms          -0.0942      0.086     -1.098      0.274      -0.264       0.076
# Floor_Area              0.3563      0.078      4.563      0.000       0.202       0.511
# Land_Area           -2.209e-15   6.81e-16     -3.246      0.002   -3.56e-15   -8.61e-16
# BusCount                0.0970      0.078      1.239      0.218      -0.058       0.252
# SchoolCount             0.1076      0.076      1.419      0.159      -0.043       0.258
# MallCount               0.0110      0.059      0.187      0.852      -0.105       0.127
# HospitalCount          -0.1272      0.081     -1.568      0.120      -0.288       0.034
# Matched_Zonal_Value    -0.1630      0.113     -1.446      0.151      -0.386       0.060
# ==============================================================================
# Omnibus:                       41.504   Durbin-Watson:                   1.691
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.857
# Skew:                           1.412   Prob(JB):                     8.36e-20
# Kurtosis:                       6.051   Cond. No.                     5.82e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.63e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# land
# c:\Users\Leibniz\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1918: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.287
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     121.0
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):          1.01e-107
# Time:                        00:08:17   Log-Likelihood:                 229.09
# No. Observations:                1508   AIC:                            -446.2
# Df Residuals:                    1502   BIC:                            -414.3
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.2808      0.019     14.688      0.000       0.243       0.318
# LRTHubDist             -0.2007      0.023     -8.667      0.000      -0.246      -0.155
# Num_Bedrooms          5.73e-17   5.06e-18     11.326      0.000    4.74e-17    6.72e-17
# Num_Bathrooms       -2.517e-17   7.71e-18     -3.266      0.001   -4.03e-17   -1.01e-17
# Floor_Area           6.307e-18   7.14e-18      0.884      0.377   -7.69e-18    2.03e-17
# Land_Area               0.4735      0.032     14.582      0.000       0.410       0.537
# BusCount                0.3344      0.024     13.995      0.000       0.288       0.381
# SchoolCount            -0.0693      0.024     -2.858      0.004      -0.117      -0.022
# MallCount                    0          0        nan        nan           0           0
# HospitalCount                0          0        nan        nan           0           0
# Matched_Zonal_Value    -0.2599      0.060     -4.298      0.000      -0.378      -0.141
# ==============================================================================
# Omnibus:                      220.076   Durbin-Watson:                   1.448
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              342.440
# Skew:                           0.998   Prob(JB):                     4.37e-75
# Kurtosis:                       4.211   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# commercial
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.482
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     12.68
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):           9.61e-13
# Time:                        00:08:17   Log-Likelihood:                 41.375
# No. Observations:                 118   AIC:                            -64.75
# Df Residuals:                     109   BIC:                            -39.81
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.2789      0.056      4.955      0.000       0.167       0.390
# LRTHubDist             -0.4313      0.115     -3.765      0.000      -0.658      -0.204
# Num_Bedrooms         3.025e-16   7.48e-17      4.046      0.000    1.54e-16    4.51e-16
# Num_Bathrooms        1.542e-17   2.42e-17      0.636      0.526   -3.26e-17    6.35e-17
# Floor_Area              0.2545      0.079      3.228      0.002       0.098       0.411
# Land_Area               0.4283      0.084      5.095      0.000       0.262       0.595
# BusCount                0.1531      0.082      1.877      0.063      -0.009       0.315
# SchoolCount            -0.2887      0.100     -2.898      0.005      -0.486      -0.091
# MallCount              -0.1032      0.070     -1.477      0.143      -0.242       0.035
# HospitalCount           0.0265      0.090      0.295      0.768      -0.151       0.204
# Matched_Zonal_Value     0.0846      0.095      0.894      0.373      -0.103       0.272
# ==============================================================================
# Omnibus:                       32.151   Durbin-Watson:                   1.567
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.788
# Skew:                           1.309   Prob(JB):                     1.54e-11
# Kurtosis:                       4.809   Cond. No.                     2.80e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.24e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# house
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                     3296.
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):               0.00
# Time:                        00:08:17   Log-Likelihood:                 11095.
# No. Observations:               14067   AIC:                        -2.217e+04
# Df Residuals:                   14056   BIC:                        -2.208e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0426      0.004      9.803      0.000       0.034       0.051
# LRTHubDist             -0.1290      0.005    -23.815      0.000      -0.140      -0.118
# Num_Bedrooms            0.0021      0.005      0.428      0.669      -0.008       0.012
# Num_Bathrooms           0.0159      0.005      3.039      0.002       0.006       0.026
# Floor_Area              0.8826      0.009    102.589      0.000       0.866       0.900
# Land_Area               0.1691      0.006     28.893      0.000       0.158       0.181
# BusHubDist             -0.1044      0.005    -22.291      0.000      -0.114      -0.095
# SchoolHubDist           0.0225      0.005      4.521      0.000       0.013       0.032
# MallHubDist            -0.0073      0.005     -1.337      0.181      -0.018       0.003
# HospitalHubDist         0.0495      0.005      9.546      0.000       0.039       0.060
# Matched_Zonal_Value    -0.1180      0.005    -23.752      0.000      -0.128      -0.108
# ==============================================================================
# Omnibus:                     3034.001   Durbin-Watson:                   1.442
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12311.125
# Skew:                           1.019   Prob(JB):                         0.00
# Kurtosis:                       7.105   Cond. No.                         17.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# condo
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.663
# Model:                            OLS   Adj. R-squared:                  0.663
# Method:                 Least Squares   F-statistic:                     2623.
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):               0.00
# Time:                        00:08:17   Log-Likelihood:                 7469.1
# No. Observations:               12009   AIC:                        -1.492e+04
# Df Residuals:                   11999   BIC:                        -1.484e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0075      0.006      1.250      0.211      -0.004       0.019
# LRTHubDist             -0.0383      0.007     -5.553      0.000      -0.052      -0.025
# Num_Bedrooms           -0.2949      0.008    -35.748      0.000      -0.311      -0.279
# Num_Bathrooms           0.1385      0.007     19.701      0.000       0.125       0.152
# Floor_Area              1.0779      0.009    119.244      0.000       1.060       1.096
# Land_Area           -6.522e-17   3.67e-18    -17.753      0.000   -7.24e-17    -5.8e-17
# BusHubDist              0.0267      0.006      4.548      0.000       0.015       0.038
# SchoolHubDist           0.0119      0.006      2.018      0.044       0.000       0.023
# MallHubDist             0.0029      0.006      0.520      0.603      -0.008       0.014
# HospitalHubDist         0.0792      0.006     13.888      0.000       0.068       0.090
# Matched_Zonal_Value    -0.0446      0.008     -5.785      0.000      -0.060      -0.029
# ==============================================================================
# Omnibus:                      656.363   Durbin-Watson:                   1.440
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2652.925
# Skew:                           0.056   Prob(JB):                         0.00
# Kurtosis:                       5.300   Cond. No.                     4.08e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.6e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# apartment
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.399
# Model:                            OLS   Adj. R-squared:                  0.351
# Method:                 Least Squares   F-statistic:                     8.268
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):           2.33e-09
# Time:                        00:08:17   Log-Likelihood:                 34.250
# No. Observations:                 122   AIC:                            -48.50
# Df Residuals:                     112   BIC:                            -20.46
# Df Model:                           9
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1452      0.061      2.361      0.020       0.023       0.267
# LRTHubDist             -0.1460      0.078     -1.861      0.065      -0.302       0.009
# Num_Bedrooms            0.4063      0.101      4.038      0.000       0.207       0.606
# Num_Bathrooms          -0.1128      0.087     -1.304      0.195      -0.284       0.059
# Floor_Area              0.3521      0.077      4.545      0.000       0.199       0.506
# Land_Area           -1.817e-17   4.09e-17     -0.444      0.658   -9.92e-17    6.28e-17
# BusHubDist             -0.0831      0.074     -1.121      0.264      -0.230       0.064
# SchoolHubDist           0.0667      0.088      0.759      0.449      -0.107       0.241
# MallHubDist            -0.0776      0.084     -0.929      0.355      -0.243       0.088
# HospitalHubDist         0.1541      0.076      2.035      0.044       0.004       0.304
# Matched_Zonal_Value    -0.1540      0.114     -1.357      0.178      -0.379       0.071
# ==============================================================================
# Omnibus:                       39.217   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.209
# Skew:                           1.325   Prob(JB):                     8.54e-19
# Kurtosis:                       6.057   Cond. No.                     9.70e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.51e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# land
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.312
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     97.14
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):          4.35e-117
# Time:                        00:08:17   Log-Likelihood:                 255.80
# No. Observations:                1508   AIC:                            -495.6
# Df Residuals:                    1500   BIC:                            -453.1
# Df Model:                           7
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.3896      0.020     19.894      0.000       0.351       0.428
# LRTHubDist             -0.1574      0.029     -5.434      0.000      -0.214      -0.101
# Num_Bedrooms        -2.697e-17   1.52e-17     -1.769      0.077   -5.69e-17    2.93e-18
# Num_Bathrooms       -1.131e-16   1.56e-17     -7.255      0.000   -1.44e-16   -8.25e-17
# Floor_Area           5.695e-18   7.55e-18      0.755      0.451   -9.11e-18    2.05e-17
# Land_Area               0.5118      0.033     15.615      0.000       0.448       0.576
# BusHubDist             -0.3954      0.033    -11.863      0.000      -0.461      -0.330
# SchoolHubDist           0.1739      0.026      6.674      0.000       0.123       0.225
# MallHubDist            -0.0116      0.036     -0.321      0.748      -0.083       0.059
# HospitalHubDist        -0.1085      0.030     -3.572      0.000      -0.168      -0.049
# Matched_Zonal_Value    -0.2419      0.060     -4.059      0.000      -0.359      -0.125
# ==============================================================================
# Omnibus:                      250.203   Durbin-Watson:                   1.490
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              415.011
# Skew:                           1.079   Prob(JB):                     7.61e-91
# Kurtosis:                       4.395   Cond. No.                     3.32e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.95e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# commercial
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.531
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     15.44
# Date:                Fri, 17 Jan 2025   Prob (F-statistic):           5.48e-15
# Time:                        00:08:17   Log-Likelihood:                 47.274
# No. Observations:                 118   AIC:                            -76.55
# Df Residuals:                     109   BIC:                            -51.61
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1761      0.053      3.337      0.001       0.072       0.281
# LRTHubDist             -0.3490      0.104     -3.361      0.001      -0.555      -0.143
# Num_Bedrooms         1.441e-16   2.35e-17      6.124      0.000    9.74e-17    1.91e-16
# Num_Bathrooms        7.801e-17   6.14e-17      1.270      0.207   -4.38e-17       2e-16
# Floor_Area              0.1692      0.069      2.467      0.015       0.033       0.305
# Land_Area               0.4866      0.079      6.132      0.000       0.329       0.644
# BusHubDist              0.0074      0.067      0.111      0.912      -0.125       0.140
# SchoolHubDist           0.1462      0.058      2.532      0.013       0.032       0.261
# MallHubDist            -0.3275      0.091     -3.609      0.000      -0.507      -0.148
# HospitalHubDist         0.2254      0.074      3.056      0.003       0.079       0.372
# Matched_Zonal_Value     0.1319      0.090      1.466      0.146      -0.046       0.310
# ==============================================================================
# Omnibus:                       28.157   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.395
# Skew:                           1.175   Prob(JB):                     1.03e-09
# Kurtosis:                       4.703   Cond. No.                     1.04e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.04e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
for count_distance in ["count", "distance"]:
    for category in general_df["Category"].unique().tolist():
        category_df = general_df[general_df["Category"]==category]
        
        print(category)
        print(cv_model2(category_df, count_distance, True, True))
        print("\n")
# Out:
# house
# Average Mean Squared Error (MSE): 0.0133
# Average R-squared (R²): 0.7065
#                 Feature  Average Importance  Average P>|t|
# 7           SchoolCount              0.0173         0.3625
# 2          Num_Bedrooms             -0.0033         0.3148
# 3         Num_Bathrooms              0.0153         0.2800
# 8             MallCount             -0.0088         0.1828
# 0                 const              0.0203         0.1321
# 9         HospitalCount             -0.0530         0.0000
# 10  Matched_Zonal_Value             -0.0959         0.0000
# 1            LRTHubDist             -0.1173         0.0000
# 6              BusCount              0.1267         0.0000
# 5             Land_Area              0.1955         0.0000
# 4            Floor_Area              0.8381         0.0000
#
#
# condo
# Average Mean Squared Error (MSE): 0.0217
# Average R-squared (R²): 0.6624
#                 Feature  Average Importance  Average P>|t|
# 9         HospitalCount             -0.0150         0.2314
# 7           SchoolCount              0.0009         0.1890
# 5             Land_Area             -0.0000         0.1774
# 8             MallCount              0.0265         0.1319
# 6              BusCount             -0.0138         0.0864
# 1            LRTHubDist             -0.0314         0.0733
# 0                 const              0.0487         0.0012
# 10  Matched_Zonal_Value             -0.0460         0.0000
# 3         Num_Bathrooms              0.1384         0.0000
# 2          Num_Bedrooms             -0.2939         0.0000
# 4            Floor_Area              1.0829         0.0000
#
#
# apartment
# Average Mean Squared Error (MSE): 0.0480
# Average R-squared (R²): 0.4125
#                 Feature  Average Importance  Average P>|t|
# 8             MallCount              0.0075         0.6121
# 1            LRTHubDist             -0.0777         0.4517
# 6              BusCount              0.0919         0.4203
# 3         Num_Bathrooms             -0.0914         0.3706
# 7           SchoolCount              0.0844         0.3277
# 9         HospitalCount             -0.1266         0.2840
# 10  Matched_Zonal_Value             -0.1543         0.2820
# 0                 const              0.1063         0.2748
# 5             Land_Area              0.0000         0.1239
# 4            Floor_Area              0.3569         0.0003
# 2          Num_Bedrooms              0.4357         0.0003
#
#
# land
# Average Mean Squared Error (MSE): 0.0542
# Average R-squared (R²): 0.2898
#                 Feature  Average Importance  Average P>|t|
# 7           SchoolCount             -0.0581         0.0995
# 3         Num_Bathrooms              0.0000         0.0594
# 2          Num_Bedrooms             -0.0000         0.0092
# 4            Floor_Area             -0.0000         0.0020
# 10  Matched_Zonal_Value             -0.2486         0.0015
# 6              BusCount              0.3219         0.0000
# 1            LRTHubDist             -0.1977         0.0000
# 5             Land_Area              0.4781         0.0000
# 0                 const              0.2768         0.0000
# 8             MallCount              0.0000            NaN
# 9         HospitalCount              0.0000            NaN
#
#
# commercial
# Average Mean Squared Error (MSE): 0.0423
# Average R-squared (R²): 0.5046
#                 Feature  Average Importance  Average P>|t|
# 9         HospitalCount              0.0221         0.6207
# 10  Matched_Zonal_Value              0.0980         0.4824
# 8             MallCount             -0.0980         0.2924
# 6              BusCount              0.1528         0.1630
# 3         Num_Bathrooms              0.0000         0.1131
# 2          Num_Bedrooms              0.0000         0.0702
# 1            LRTHubDist             -0.4233         0.0175
# 4            Floor_Area              0.2568         0.0174
# 7           SchoolCount             -0.2793         0.0168
# 5             Land_Area              0.4351         0.0019
# 0                 const              0.2678         0.0002
#
#
# house
# Average Mean Squared Error (MSE): 0.0139
# Average R-squared (R²): 0.6975
#                 Feature  Average Importance  Average P>|t|
# 3         Num_Bathrooms              0.0165         0.3371
# 8           MallHubDist             -0.0107         0.1963
# 2          Num_Bedrooms              0.0043         0.0904
# 7         SchoolHubDist              0.0247         0.0299
# 0                 const              0.0402         0.0001
# 9       HospitalHubDist              0.0551         0.0000
# 10  Matched_Zonal_Value             -0.1140         0.0000
# 6            BusHubDist             -0.1057         0.0000
# 1            LRTHubDist             -0.1278         0.0000
# 5             Land_Area              0.1749         0.0000
# 4            Floor_Area              0.8711         0.0000
#
#
# condo
# Average Mean Squared Error (MSE): 0.0207
# Average R-squared (R²): 0.6674
#                 Feature  Average Importance  Average P>|t|
# 8           MallHubDist              0.0021         0.3322
# 0                 const              0.0035         0.3224
# 7         SchoolHubDist              0.0122         0.2235
# 1            LRTHubDist             -0.0348         0.1547
# 6            BusHubDist              0.0246         0.0173
# 10  Matched_Zonal_Value             -0.0441         0.0000
# 9       HospitalHubDist              0.0768         0.0000
# 5             Land_Area              0.0000         0.0000
# 3         Num_Bathrooms              0.1375         0.0000
# 2          Num_Bedrooms             -0.2872         0.0000
# 4            Floor_Area              1.0741         0.0000
#
#
# apartment
# Average Mean Squared Error (MSE): 0.0412
# Average R-squared (R²): 0.4068
#                 Feature  Average Importance  Average P>|t|
# 8           MallHubDist             -0.0697         0.5246
# 7         SchoolHubDist              0.0715         0.4889
# 6            BusHubDist             -0.0718         0.4348
# 3         Num_Bathrooms             -0.1109         0.2961
# 10  Matched_Zonal_Value             -0.1541         0.2567
# 5             Land_Area              0.0000         0.1942
# 9       HospitalHubDist              0.1467         0.1521
# 1            LRTHubDist             -0.1487         0.1096
# 0                 const              0.1394         0.0556
# 2          Num_Bedrooms              0.4062         0.0008
# 4            Floor_Area              0.3553         0.0004
#
#
# land
# Average Mean Squared Error (MSE): 0.0532
# Average R-squared (R²): 0.3167
#                 Feature  Average Importance  Average P>|t|
# 8           MallHubDist             -0.0155         0.3616
# 9       HospitalHubDist             -0.0934         0.1658
# 3         Num_Bathrooms             -0.0000         0.1270
# 2          Num_Bedrooms              0.0000         0.0627
# 4            Floor_Area              0.0000         0.0105
# 10  Matched_Zonal_Value             -0.2436         0.0010
# 1            LRTHubDist             -0.1585         0.0000
# 7         SchoolHubDist              0.1582         0.0000
# 6            BusHubDist             -0.3945         0.0000
# 5             Land_Area              0.5225         0.0000
# 0                 const              0.3905         0.0000
#
#
# commercial
# Average Mean Squared Error (MSE): 0.0433
# Average R-squared (R²): 0.5567
#                 Feature  Average Importance  Average P>|t|
# 3         Num_Bathrooms              0.0000         0.3912
# 6            BusHubDist              0.0175         0.3649
# 10  Matched_Zonal_Value              0.1323         0.3094
# 2          Num_Bedrooms             -0.0000         0.1439
# 8           MallHubDist             -0.3292         0.0784
# 4            Floor_Area              0.1833         0.0669
# 1            LRTHubDist             -0.3496         0.0585
# 9       HospitalHubDist              0.2284         0.0567
# 7         SchoolHubDist              0.1427         0.0458
# 0                 const              0.1690         0.0421
# 5             Land_Area              0.4842         0.0002

# %% [markdown]
# # END
