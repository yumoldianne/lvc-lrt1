# %%
# %run "01 Functions.ipynb"

# %% [markdown]
# ## Preprocessing

# %%
count_vif = calculate_vif(X_subset(merged_df, "count", True))
print(count_vif[count_vif["VIF"]>5])

distance_vif = calculate_vif(X_subset(merged_df, "distance", True))
print(distance_vif[distance_vif["VIF"]>5])

# CMCI cols removed due to high VIF
# Out:
#                       Feature        VIF
# 7                   MallCount   6.023998
# 9                    ATMCount   5.658701
# 10      employment_generation  15.111702
# 11        financial_deepening  12.231806
# 12         local_economy_size   7.388820
# 13  safety_compliant_business  18.444081
#                       Feature        VIF
# 6             HospitalHubDist   6.331391
# 7                 MallHubDist   6.135757
# 9                  ATMHubDist   5.024478
# 10      employment_generation  15.476342
# 11        financial_deepening  11.463019
# 12         local_economy_size   6.246232
# 13  safety_compliant_business  20.565766

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### General

# %%
for count_distance in ["count", "distance"]:
    # print(f"basic model - {count_distance}", basic_model(merged_df, count_distance, True, True))
    # print(f"cv model new - {count_distance}", cv_new(merged_df, count_distance, True, True))
    print(f"cv model - {count_distance}", cv_model2(merged_df, count_distance, True, True))
# Out:
# ===== Cross-Validation OLS Results =====
# Average Mean Squared Error (MSE): 0.4743
# Average R²: 0.5254
#
# Coefficients:
#                    Feature  Average Coefficient  Average P>|t|
#                Floor_Area               0.7076         0.0000
#       financial_deepening               0.2987         0.0000
#        local_economy_size               0.4402         0.0000
#     employment_generation              -0.3243         0.0000
#                 Land_Area               0.1640         0.0000
# safety_compliant_business              -0.2487         0.0000
#                  BusCount               0.1253         0.0000
#              Num_Bedrooms              -0.1675         0.0000
#               SchoolCount              -0.0739         0.0000
#                 MallCount               0.1294         0.0000
#             HospitalCount              -0.0572         0.0000
#                  ATMCount              -0.0774         0.0000
#             Num_Bathrooms               0.0786         0.0000
#                LRTHubDist              -0.0146         0.0012
#                     const               0.0000         0.8609
# cv model - count                       Feature  Average Coefficient  Average P>|t|
# 3                  Floor_Area               0.7076         0.0000
# 12        financial_deepening               0.2987         0.0000
# 13         local_economy_size               0.4402         0.0000
# 11      employment_generation              -0.3243         0.0000
# 4                   Land_Area               0.1640         0.0000
# 14  safety_compliant_business              -0.2487         0.0000
# 6                    BusCount               0.1253         0.0000
# 1                Num_Bedrooms              -0.1675         0.0000
# 9                 SchoolCount              -0.0739         0.0000
# 8                   MallCount               0.1294         0.0000
# 7               HospitalCount              -0.0572         0.0000
# 10                   ATMCount              -0.0774         0.0000
# 2               Num_Bathrooms               0.0786         0.0000
# 5                  LRTHubDist              -0.0146         0.0012
# 0                       const               0.0000         0.8609
#
# ===== Cross-Validation OLS Results =====
# Average Mean Squared Error (MSE): 0.4718
# Average R²: 0.5280
#
# Coefficients:
#                    Feature  Average Coefficient  Average P>|t|
#                Floor_Area               0.7169         0.0000
#       financial_deepening               0.3063         0.0000
#        local_economy_size               0.4624         0.0000
#     employment_generation              -0.3317         0.0000
#                 Land_Area               0.1717         0.0000
#                BusHubDist              -0.1406         0.0000
# safety_compliant_business              -0.2568         0.0000
#           HospitalHubDist               0.1090         0.0000
#              Num_Bedrooms              -0.1616         0.0000
#             SchoolHubDist               0.0699         0.0000
#               MallHubDist              -0.0644         0.0000
#             Num_Bathrooms               0.0792         0.0000
#                LRTHubDist              -0.0244         0.0000
#                ATMHubDist               0.0026         0.5885
#                     const              -0.0000         0.8462
# cv model - distance                       Feature  Average Coefficient  Average P>|t|
# 3                  Floor_Area               0.7169         0.0000
# 12        financial_deepening               0.3063         0.0000
# 13         local_economy_size               0.4624         0.0000
# 11      employment_generation              -0.3317         0.0000
# 4                   Land_Area               0.1717         0.0000
# 6                  BusHubDist              -0.1406         0.0000
# 14  safety_compliant_business              -0.2568         0.0000
# 7             HospitalHubDist               0.1090         0.0000
# 1                Num_Bedrooms              -0.1616         0.0000
# 9               SchoolHubDist               0.0699         0.0000
# 8                 MallHubDist              -0.0644         0.0000
# 2               Num_Bathrooms               0.0792         0.0000
# 5                  LRTHubDist              -0.0244         0.0000
# 10                 ATMHubDist               0.0026         0.5885
# 0                       const              -0.0000         0.8462

# %% [markdown]
# ### Categories - RR & CR

# %%
for count_distance in ["count", "distance"]:
    for category in merged_df["Property Type"].unique().tolist():
        category_df = merged_df[merged_df["Property Type"]==category]
        
        print(category, "- ", count_distance)
        print(cv_model2(category_df, count_distance, True, True))
        print("\n")
# Out:
# RR -  count
#
# ===== Cross-Validation OLS Results =====
# Average Mean Squared Error (MSE): 0.4316
# Average R²: 0.5683
#
# Coefficients:
#                    Feature  Average Coefficient  Average P>|t|
#                Floor_Area               0.8538         0.0000
#        local_economy_size               0.4226         0.0000
#       financial_deepening               0.2682         0.0000
#                 Land_Area              -0.2343         0.0000
#     employment_generation              -0.3056         0.0000
# safety_compliant_business              -0.2494         0.0000
#                  BusCount               0.1194         0.0000
#               SchoolCount              -0.0854         0.0000
#                 MallCount               0.1319         0.0000
#             HospitalCount              -0.0723         0.0000
#                  ATMCount              -0.0980         0.0000
#             Num_Bathrooms               0.0792         0.0000
#                LRTHubDist              -0.0086         0.0703
#              Num_Bedrooms              -0.0026         0.7022
#                     const              -0.0000         0.7649
#                       Feature  Average Coefficient  Average P>|t|
# 3                  Floor_Area               0.8538         0.0000
# 13         local_economy_size               0.4226         0.0000
# 12        financial_deepening               0.2682         0.0000
# 4                   Land_Area              -0.2343         0.0000
# 11      employment_generation              -0.3056         0.0000
# 14  safety_compliant_business              -0.2494         0.0000
# 6                    BusCount               0.1194         0.0000
# 9                 SchoolCount              -0.0854         0.0000
# 8                   MallCount               0.1319         0.0000
# 7               HospitalCount              -0.0723         0.0000
# 10                   ATMCount              -0.0980         0.0000
# 2               Num_Bathrooms               0.0792         0.0000
# 5                  LRTHubDist              -0.0086         0.0703
# 1                Num_Bedrooms              -0.0026         0.7022
# 0                       const              -0.0000         0.7649
#
#
# CR -  count
#
# ===== Cross-Validation OLS Results =====
# Average Mean Squared Error (MSE): 0.4610
# Average R²: 0.5387
#
# Coefficients:
#                    Feature  Average Coefficient  Average P>|t|
#                 Land_Area               0.6557         0.0000
#                LRTHubDist              -0.2826         0.0000
#       financial_deepening               0.1907         0.0000
#        local_economy_size               0.1390         0.0000
# safety_compliant_business              -0.1340         0.0000
#                 MallCount               0.0913         0.0003
#                Floor_Area              -0.0470         0.0003
#                  BusCount               0.0442         0.0113
#               SchoolCount              -0.0348         0.0317
#              Num_Bedrooms              -0.0000         0.0468
#             Num_Bathrooms              -0.0000         0.1087
#             HospitalCount               0.0186         0.1893
#     employment_generation              -0.0216         0.2520
#                  ATMCount              -0.0136         0.5905
#                     const               0.0000         0.6043
#                       Feature  Average Coefficient  Average P>|t|
# 4                   Land_Area               0.6557         0.0000
# 5                  LRTHubDist              -0.2826         0.0000
# 12        financial_deepening               0.1907         0.0000
# 13         local_economy_size               0.1390         0.0000
# 14  safety_compliant_business              -0.1340         0.0000
# 8                   MallCount               0.0913         0.0003
# 3                  Floor_Area              -0.0470         0.0003
# 6                    BusCount               0.0442         0.0113
# 9                 SchoolCount              -0.0348         0.0317
# 1                Num_Bedrooms              -0.0000         0.0468
# 2               Num_Bathrooms              -0.0000         0.1087
# 7               HospitalCount               0.0186         0.1893
# 11      employment_generation              -0.0216         0.2520
# 10                   ATMCount              -0.0136         0.5905
# 0                       const               0.0000         0.6043
#
#
# RR -  distance
#
# ===== Cross-Validation OLS Results =====
# Average Mean Squared Error (MSE): 0.4307
# Average R²: 0.5693
#
# Coefficients:
#                    Feature  Average Coefficient  Average P>|t|
#                Floor_Area               0.8601         0.0000
#       financial_deepening               0.2845         0.0000
#        local_economy_size               0.4512         0.0000
#                 Land_Area              -0.2271         0.0000
#     employment_generation              -0.3205         0.0000
#           HospitalHubDist               0.1224         0.0000
#                BusHubDist              -0.1396         0.0000
# safety_compliant_business              -0.2647         0.0000
#             SchoolHubDist               0.0569         0.0000
#               MallHubDist              -0.0731         0.0000
#             Num_Bathrooms               0.0827         0.0000
#                ATMHubDist               0.0413         0.0000
#                LRTHubDist              -0.0182         0.0000
#                     const               0.0000         0.7248
#              Num_Bedrooms               0.0026         0.7258
#                       Feature  Average Coefficient  Average P>|t|
# 3                  Floor_Area               0.8601         0.0000
# 12        financial_deepening               0.2845         0.0000
# 13         local_economy_size               0.4512         0.0000
# 4                   Land_Area              -0.2271         0.0000
# 11      employment_generation              -0.3205         0.0000
# 7             HospitalHubDist               0.1224         0.0000
# 6                  BusHubDist              -0.1396         0.0000
# 14  safety_compliant_business              -0.2647         0.0000
# 9               SchoolHubDist               0.0569         0.0000
# 8                 MallHubDist              -0.0731         0.0000
# 2               Num_Bathrooms               0.0827         0.0000
# 10                 ATMHubDist               0.0413         0.0000
# 5                  LRTHubDist              -0.0182         0.0000
# 0                       const               0.0000         0.7248
# 1                Num_Bedrooms               0.0026         0.7258
#
#
# CR -  distance
#
# ===== Cross-Validation OLS Results =====
# Average Mean Squared Error (MSE): 0.4578
# Average R²: 0.5418
#
# Coefficients:
#                    Feature  Average Coefficient  Average P>|t|
#                 Land_Area               0.6454         0.0000
#                LRTHubDist              -0.2731         0.0000
#       financial_deepening               0.1544         0.0000
#        local_economy_size               0.1145         0.0000
#               MallHubDist              -0.0905         0.0000
# safety_compliant_business              -0.1043         0.0000
#           HospitalHubDist               0.0800         0.0000
#                ATMHubDist              -0.0684         0.0009
#                BusHubDist              -0.0420         0.0046
#             Num_Bathrooms               0.0000         0.0048
#              Num_Bedrooms              -0.0000         0.0060
#             SchoolHubDist               0.0353         0.0129
#                Floor_Area              -0.0201         0.0800
#                     const               0.0002         0.5712
#     employment_generation              -0.0110         0.5802
#                       Feature  Average Coefficient  Average P>|t|
# 4                   Land_Area               0.6454         0.0000
# 5                  LRTHubDist              -0.2731         0.0000
# 12        financial_deepening               0.1544         0.0000
# 13         local_economy_size               0.1145         0.0000
# 8                 MallHubDist              -0.0905         0.0000
# 14  safety_compliant_business              -0.1043         0.0000
# 7             HospitalHubDist               0.0800         0.0000
# 10                 ATMHubDist              -0.0684         0.0009
# 6                  BusHubDist              -0.0420         0.0046
# 2               Num_Bathrooms               0.0000         0.0048
# 1                Num_Bedrooms              -0.0000         0.0060
# 9               SchoolHubDist               0.0353         0.0129
# 3                  Floor_Area              -0.0201         0.0800
# 0                       const               0.0002         0.5712
# 11      employment_generation              -0.0110         0.5802

# %% [markdown]
# ### Categories

# %%
# %run "01 Functions.ipynb"
for count_distance in ["count"]:#, "distance"]:
    for category in merged_df["Category"].unique().tolist():
        category_df = merged_df[merged_df["Category"]==category]
        
        print(category + "- " + count_distance)
        cv_model2(category_df, count_distance, True, True)
        print("\n")
# Out:
# house- count
#
# ===== Cross-Validation OLS Results =====
# Average Mean Squared Error (MSE): 0.2665
# Average R²: 0.7335
#
# Coefficients:
#                    Feature  Average Coefficient  Average P>|t|
#                Floor_Area               0.6206         0.0000
#                 Land_Area               0.2383         0.0000
#                  BusCount               0.1386         0.0000
#        local_economy_size               0.1253         0.0000
#                  ATMCount               0.0838         0.0000
#                LRTHubDist              -0.0697         0.0000
#       financial_deepening               0.1580         0.0000
#     employment_generation              -0.1405         0.0000
#             Num_Bathrooms               0.0612         0.0000
#                 MallCount               0.0422         0.0000
#             HospitalCount              -0.0382         0.0000
#              Num_Bedrooms              -0.0350         0.0000
#               SchoolCount              -0.0266         0.0000
# safety_compliant_business              -0.0573         0.0000
#                     const               0.0000         0.5772
#
#
# condo- count
#
# ===== Cross-Validation OLS Results =====
# Average Mean Squared Error (MSE): 0.2855
# Average R²: 0.7144
#
# Coefficients:
#                    Feature  Average Coefficient  Average P>|t|
#                Floor_Area               0.7812         0.0000
#        local_economy_size               0.2897         0.0000
#              Num_Bedrooms              -0.1247         0.0000
#             Num_Bathrooms               0.0965         0.0000
#       financial_deepening               0.1182         0.0000
#     employment_generation              -0.2186         0.0000
#             HospitalCount              -0.0666         0.0000
#                 Land_Area               0.0000         0.0000
#               SchoolCount              -0.0551         0.0000
#                  BusCount               0.0678         0.0000
#                  ATMCount              -0.0826         0.0000
# safety_compliant_business              -0.1023         0.0000
#                 MallCount               0.0425         0.0000
#                LRTHubDist               0.0150         0.0058
#                     const              -0.0000         0.8383
#
#
# land- count
#
# ===== Cross-Validation OLS Results =====
# Average Mean Squared Error (MSE): 0.4661
# Average R²: 0.5336
#
# Coefficients:
#                    Feature  Average Coefficient  Average P>|t|
#                 Land_Area               0.5147         0.0000
#                LRTHubDist              -0.3532         0.0000
#       financial_deepening               0.1408         0.0000
#                  ATMCount               0.1149         0.0000
# safety_compliant_business              -0.1141         0.0000
#     employment_generation               0.0721         0.0010
#                  BusCount               0.0407         0.0129
#        local_economy_size               0.0393         0.0434
#               SchoolCount               0.0292         0.0590
#             Num_Bathrooms               0.0000         0.0916
#                 MallCount               0.0257         0.1402
#              Num_Bedrooms              -0.0000         0.1522
#                Floor_Area              -0.0000         0.1978
#             HospitalCount               0.0111         0.3954
#                     const              -0.0000         0.8382
#
#
# commercial- count
#
# ===== Cross-Validation OLS Results =====
# Average Mean Squared Error (MSE): 0.4615
# Average R²: 0.5369
#
# Coefficients:
#                    Feature  Average Coefficient  Average P>|t|
#                Floor_Area               0.5889         0.0000
#                 Land_Area               0.3052         0.0000
#        local_economy_size               0.3189         0.0000
#     employment_generation              -0.2412         0.0000
#       financial_deepening               0.1160         0.0002
#                 MallCount               0.1506         0.0015
#               SchoolCount              -0.0449         0.0222
#              Num_Bedrooms               0.0000         0.0852
#                LRTHubDist              -0.0404         0.1019
#                  ATMCount              -0.0703         0.1433
#             Num_Bathrooms              -0.0000         0.2079
#             HospitalCount               0.0155         0.4809
#                  BusCount               0.0012         0.5856
#                     const               0.0001         0.6652
# safety_compliant_business               0.0184         0.6845
#
#
# apartment- count
#
# ===== Cross-Validation OLS Results =====
# Average Mean Squared Error (MSE): 0.6776
# Average R²: 0.2966
#
# Coefficients:
#                    Feature  Average Coefficient  Average P>|t|
#        local_economy_size               0.5872         0.0000
#                Floor_Area               0.3588         0.0000
#              Num_Bedrooms               0.3292         0.0001
#     employment_generation              -0.5391         0.0010
#       financial_deepening               0.1991         0.0455
#                  ATMCount              -0.2030         0.0518
#                  BusCount               0.1901         0.0607
#                 MallCount               0.1710         0.0777
#                 Land_Area               0.0000         0.3349
#             HospitalCount              -0.0904         0.3546
#             Num_Bathrooms              -0.0539         0.4459
#               SchoolCount              -0.0524         0.4722
# safety_compliant_business               0.0298         0.5541
#                     const               0.0014         0.7012
#                LRTHubDist              -0.0251         0.7324

# %% [markdown]
# # END
