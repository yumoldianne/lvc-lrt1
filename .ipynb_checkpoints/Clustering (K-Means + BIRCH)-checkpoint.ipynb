# %% [markdown]
# ### Clustering (K-Means + BIRCH)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, Birch, DBSCAN
from kneed import KneeLocator
from sklearn.metrics import silhouette_score

# %%
# Load your data
data = pd.read_csv('merged_df.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72019 entries, 0 to 72018
# Data columns (total 45 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           72019 non-null  int64
#  1   Location                                             72019 non-null  object
#  2   URL                                                  72019 non-null  object
#  3   SKU                                                  72019 non-null  object
#  4   Title                                                72014 non-null  object
#  5   Price                                                72019 non-null  float64
#  6   Category                                             72019 non-null  object
#  7   Num_Bedrooms                                         72019 non-null  float64
#  8   Num_Bathrooms                                        72019 non-null  float64
#  9   Floor_Area                                           72019 non-null  float64
#  10  Land_Area                                            72019 non-null  float64
#  11  Description                                          71856 non-null  object
#  12  Agent_Name                                           72019 non-null  object
#  13  Agent_Link                                           72019 non-null  object
#  14  Agent_Verification                                   72019 non-null  object
#  15  File                                                 72019 non-null  object
#  16  Latitude                                             72019 non-null  float64
#  17  Longitude                                            72019 non-null  float64
#  18  LRTHubName                                           72019 non-null  object
#  19  LRTHubDist                                           72019 non-null  float64
#  20  BusHubName                                           72019 non-null  object
#  21  BusHubDist                                           72019 non-null  float64
#  22  HospitalHubName                                      72019 non-null  object
#  23  HospitalHubDist                                      72019 non-null  float64
#  24  MallHubName                                          72019 non-null  object
#  25  MallHubDist                                          72019 non-null  float64
#  26  SchoolHubName                                        72019 non-null  object
#  27  SchoolHubDist                                        72019 non-null  float64
#  28  BusCount                                             72019 non-null  int64
#  29  HospitalCount                                        72019 non-null  int64
#  30  MallCount                                            72019 non-null  int64
#  31  SchoolCount                                          72019 non-null  int64
#  32  Concat                                               72019 non-null  object
#  33  Property Type                                        72019 non-null  object
#  34  Matched_City                                         72019 non-null  object
#  35  PROVINCE / LGU                                       72019 non-null  object
#  36  employment_generation                                72019 non-null  float64
#  37  financial_deepening                                  72019 non-null  float64
#  38  local_economy_growth                                 72019 non-null  float64
#  39  local_economy_size                                   72019 non-null  float64
#  40  presence_of_business_and_professional_organizations  72019 non-null  float64
#  41  safety_compliant_business                            72019 non-null  float64
#  42  ATMHubName                                           72019 non-null  int64
#  43  ATMHubDist                                           72019 non-null  float64
#  44  ATMCount                                             72019 non-null  int64
# dtypes: float64(19), int64(7), object(19)
# memory usage: 24.7+ MB

# %%
house_df = data[data['Category'] == 'house']
condo_df = data[data['Category'] == 'condo']
apt_df = data[data['Category'] == 'apartment']
com_df = data[data['Category'] == 'commercial']
land_df = data[data['Category'] == 'land']

# %%
X_house = house_df[['Price','Num_Bedrooms', 'Num_Bathrooms', 'Floor_Area', 'Land_Area', 'LRTHubDist', 'BusCount', 'MallCount', 
                    'SchoolCount', 'HospitalCount', 'ATMCount', 'employment_generation', 'local_economy_growth', 
                    'local_economy_size', 'presence_of_business_and_professional_organizations', 'safety_compliant_business']]
X_condo = condo_df[['Price','Num_Bedrooms', 'Num_Bathrooms', 'Floor_Area', 'Land_Area', 'LRTHubDist', 'BusCount', 'MallCount', 
                    'SchoolCount', 'HospitalCount', 'ATMCount', 'employment_generation', 'local_economy_growth', 
                    'local_economy_size', 'presence_of_business_and_professional_organizations', 'safety_compliant_business']]
X_apt = apt_df[['Price','Num_Bedrooms', 'Num_Bathrooms', 'Floor_Area', 'Land_Area', 'LRTHubDist', 'BusCount', 'MallCount', 
                    'SchoolCount', 'HospitalCount', 'ATMCount', 'employment_generation', 'local_economy_growth', 
                    'local_economy_size', 'presence_of_business_and_professional_organizations', 'safety_compliant_business']]
X_com = com_df[['Price','Num_Bedrooms', 'Num_Bathrooms', 'Floor_Area', 'Land_Area', 'LRTHubDist', 'BusCount', 'MallCount', 
                    'SchoolCount', 'HospitalCount', 'ATMCount', 'employment_generation', 'local_economy_growth', 
                    'local_economy_size', 'presence_of_business_and_professional_organizations', 'safety_compliant_business']]
X_land = land_df[['Price','Num_Bedrooms', 'Num_Bathrooms', 'Floor_Area', 'Land_Area', 'LRTHubDist', 'BusCount', 'MallCount', 
                    'SchoolCount', 'HospitalCount', 'ATMCount', 'employment_generation', 'local_economy_growth', 
                    'local_economy_size', 'presence_of_business_and_professional_organizations', 'safety_compliant_business']]

# %% [markdown]
# ### House

# %%
def find_optimal_clusters(X, max_clusters=10):
    """
    Finds the optimal number of clusters using the Elbow Method.
    
    Parameters:
        X (array-like): The dataset to cluster.
        max_clusters (int): Maximum number of clusters to test (default: 10).
    
    Returns:
        int: The optimal number of clusters.
    """
    inertias = []

    # Try different cluster sizes
    for k in range(1, max_clusters + 1):
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(X)
        inertias.append(kmeans.inertia_)

    # Find the "elbow" using KneeLocator
    knee_locator = KneeLocator(range(1, max_clusters + 1), inertias, curve="convex", direction="decreasing")
    optimal_k = knee_locator.elbow

    # Handle the case where no elbow is detected
    if optimal_k is None:
        print("Warning: No clear elbow detected. Defaulting to max_clusters - 1.")
        optimal_k = max_clusters - 1  # Fallback strategy

    # Plot the Elbow Method graph
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, max_clusters + 1), inertias, marker='o', linestyle='-')
    plt.axvline(x=optimal_k, color='r', linestyle='--', label=f"Optimal k = {optimal_k}")
    plt.xlabel("Number of Clusters (k)")
    plt.ylabel("Inertia (WCSS)")
    plt.title("Elbow Method for Optimal k")
    plt.xticks(range(1, max_clusters + 1))
    plt.grid(True)
    plt.legend()
    plt.show()

    print(f"Optimal number of clusters: {optimal_k}")
    return optimal_k

# %%
find_optimal_clusters(X_house, max_clusters=10)
# Out:
# Optimal number of clusters: 3
# 3

# %%
# Standardize the data
optimal_clusters = 3  # Change this to your optimal number of clusters

# K-Means Pipeline
kmeans_pipeline = make_pipeline(StandardScaler(), KMeans(n_clusters=optimal_clusters, random_state=42))

# BIRCH Pipeline
birch_pipeline = make_pipeline(StandardScaler(), Birch(n_clusters=optimal_clusters))

# DBSCAN Pipeline (corrected)
dbscan_pipeline = make_pipeline(StandardScaler(), DBSCAN(eps=0.5, min_samples=5))

# %%
kmeans_labels = kmeans_pipeline.fit_predict(X_house)
birch_labels = birch_pipeline.fit_predict(X_house)
dbscan_labels = dbscan_pipeline.fit_predict(X_house)

# %%
# Create copies for each clustering method
x_kmeans = X_house.copy()
x_birch = X_house.copy()
x_dbscan = X_house.copy()

# Add cluster labels
x_kmeans["Cluster"] = kmeans_labels
x_birch["Cluster"] = birch_labels
x_dbscan["Cluster"] = dbscan_labels

# Save each dataset as a separate CSV file
x_kmeans.to_csv("house_kmeans.csv", index=False)
x_birch.to_csv("house_birch.csv", index=False)
x_dbscan.to_csv("house_dbscan.csv", index=False)

# %%
def get_silhouette_score(pipeline, X):
    """
    Computes the silhouette score for a clustering pipeline.

    Parameters:
        pipeline: Fitted clustering pipeline (e.g., KMeans, BIRCH, DBSCAN)
        X: Original dataset used for clustering
    
    Returns:
        Silhouette score (float) or a message if not applicable
    """
    cluster_model = pipeline.named_steps[list(pipeline.named_steps.keys())[-1]]  # Last step = clustering model
    
    # Get cluster labels
    labels = cluster_model.labels_ if hasattr(cluster_model, "labels_") else cluster_model.predict(X)
    
    # Check if the clustering model found enough clusters for a silhouette score
    if len(set(labels)) < 2:
        return "Silhouette score cannot be computed (only one cluster found)."
    
    return silhouette_score(X, labels)

# Example usage:
kmeans_silhouette = get_silhouette_score(kmeans_pipeline, X_house)
birch_silhouette = get_silhouette_score(birch_pipeline, X_house)
dbscan_silhouette = get_silhouette_score(dbscan_pipeline, X_house)

print("K-Means Silhouette Score:", kmeans_silhouette)
print("BIRCH Silhouette Score:", birch_silhouette)
print("DBSCAN Silhouette Score:", dbscan_silhouette)
# Out:
# K-Means Silhouette Score: -0.25280843030391525
# BIRCH Silhouette Score: -0.7022526358512337
# DBSCAN Silhouette Score: -0.8553214509224434

# %%
def get_top_features(pipeline, X, top_n=3):
    """
    Extracts the top `top_n` most defining features for each cluster in a clustering pipeline.
    
    Parameters:
        pipeline: Fitted clustering pipeline (e.g., KMeans, BIRCH, DBSCAN)
        X: Original DataFrame used for clustering
        top_n: Number of top features to extract per cluster (default: 3)
    
    Returns:
        DataFrame containing the top features and their values for each cluster
    """
    feature_names = X.columns  
    cluster_model = pipeline.named_steps[list(pipeline.named_steps.keys())[-1]]  # Last step = clustering model

    # Handle DBSCAN separately
    if isinstance(cluster_model, DBSCAN):
        labels = cluster_model.labels_
        unique_labels = set(labels) - {-1}  # Exclude noise points (-1)
        
        if not unique_labels:
            return "DBSCAN found no meaningful clusters."

        # Convert X to DataFrame for easier calculations
        X_df = pd.DataFrame(X, columns=feature_names)
        X_df["Cluster"] = labels  # Assign cluster labels

        global_means = X_df.iloc[:, :-1].mean()  # Mean of each feature in the dataset
        
        top_features_dict = {}

        for cluster in unique_labels:
            cluster_data = X_df[X_df["Cluster"] == cluster].iloc[:, :-1]  # Features only
            
            # Compute mean of each feature in this cluster
            cluster_means = cluster_data.mean()
            
            # Compute absolute deviation from global mean
            feature_importance = abs(cluster_means - global_means)
            
            # Get the top N most deviating features
            top_features = feature_importance.nlargest(top_n).items()
            
            # Store results
            top_features_dict[f'Cluster {cluster}'] = list(top_features)

        # Convert to DataFrame for better readability
        top_features_df = pd.DataFrame.from_dict(top_features_dict, orient='index', 
                                                 columns=[f'Top Feature {i+1}' for i in range(top_n)])
    
        return top_features_df

    # Handle K-Means & BIRCH (same as before)
    elif hasattr(cluster_model, "cluster_centers_"):
        cluster_centers = cluster_model.cluster_centers_
    elif hasattr(cluster_model, "subcluster_centers_"):
        cluster_centers = cluster_model.subcluster_centers_
    else:
        return "This clustering model does not support feature extraction."

    # Identify top N features for each cluster
    top_features_indices = np.argsort(np.abs(cluster_centers), axis=1)[:, -top_n:]

    top_features_dict = {}
    for cluster_idx, feature_indices in enumerate(top_features_indices):
        feature_info = [(feature_names[i], cluster_centers[cluster_idx, i]) for i in feature_indices]
        top_features_dict[f'Cluster {cluster_idx}'] = feature_info

    # Convert to DataFrame
    top_features_df = pd.DataFrame.from_dict(top_features_dict, orient='index', 
                                             columns=[f'Top Feature {i+1}' for i in range(top_n)])
    
    return top_features_df

# Example usage:
kmeans_features = get_top_features(kmeans_pipeline, X_house)
birch_features = get_top_features(birch_pipeline, X_house)
dbscan_features = get_top_features(dbscan_pipeline, X_house)

print("K-Means Top Features:\n", kmeans_features)
print("\nBIRCH Top Features:\n", birch_features)
print("\nDBSCAN Top Features:\n", dbscan_features)  # Now correctly calculates top features!
# Out:
# K-Means Top Features:
#                                                 Top Feature 1  \
# Cluster 0  (presence_of_business_and_professional_organiz...
# Cluster 1        (employment_generation, 0.7151543820677105)
# Cluster 2                   (SchoolCount, -1.27317079947214)
#
#                                              Top Feature 2  \
# Cluster 0     (employment_generation, -0.8061640353066462)
# Cluster 1  (safety_compliant_business, 0.7256254557517968)
# Cluster 2      (local_economy_growth, -1.5540673497744726)
#
#                                               Top Feature 3
# Cluster 0  (safety_compliant_business, -0.9437573577251036)
# Cluster 1        (local_economy_growth, 0.7396068742049327)
# Cluster 2                   (LRTHubDist, 2.732607230581358)
#
# BIRCH Top Features:
#                                                    Top Feature 1  \
# Cluster 0             (local_economy_size, -1.1519100183796642)
# Cluster 1                    (Num_Bedrooms, -1.196690088632804)
# Cluster 2          (employment_generation, -1.3534109810780441)
# Cluster 3           (local_economy_growth, -1.5412494958725502)
# Cluster 4           (local_economy_growth, -1.5412494958725502)
# ...                                                         ...
# Cluster 2612                 (Num_Bedrooms, 3.9813552149408045)
# Cluster 2613                 (SchoolCount, -1.3568151769036283)
# Cluster 2614       (employment_generation, -1.7901206771721423)
# Cluster 2615  (presence_of_business_and_professional_organiz...
# Cluster 2616                   (Floor_Area, 1.6588513334193808)
#
#                                              Top Feature 2  \
# Cluster 0     (employment_generation, -1.3534109810780441)
# Cluster 1     (employment_generation, -1.3534109810780441)
# Cluster 2                    (MallCount, 1.81439695417847)
# Cluster 3                (SchoolCount, 1.8824431702325541)
# Cluster 4                   (ATMCount, 1.6554522513360594)
# ...                                                    ...
# Cluster 2612                (LRTHubDist, 5.49756709667452)
# Cluster 2613  (employment_generation, -1.3710179152893727)
# Cluster 2614            (Num_Bedrooms, 2.6868438890474025)
# Cluster 2615             (Num_Bedrooms, 2.039588226100701)
# Cluster 2616                    (Price, 5.790033400372554)
#
#                                     Top Feature 3
# Cluster 0     (HospitalCount, 1.4758394080986366)
# Cluster 1       (SchoolCount, 2.4994447601632555)
# Cluster 2      (HospitalCount, 2.325301655631763)
# Cluster 3       (HospitalCount, 3.17476390316489)
# Cluster 4           (BusCount, 1.906048150710972)
# ...                                           ...
# Cluster 2612      (Land_Area, 12.227885134986318)
# Cluster 2613      (Land_Area, 12.948380097280767)
# Cluster 2614      (Land_Area, 11.782005055861472)
# Cluster 2615      (Land_Area, 11.649126886585856)
# Cluster 2616       (Land_Area, 22.97625260528058)
#
# [2617 rows x 3 columns]
#
# DBSCAN Top Features:
#                             Top Feature 1                     Top Feature 2  \
# Cluster 0     (Price, 44839662.89718051)  (Floor_Area, 186.66266404426642)
# Cluster 1    (Price, 39653506.601499446)   (Land_Area, 118.89877511493275)
# Cluster 2     (Price, 44687607.79197564)  (Floor_Area, 176.83878586043477)
# Cluster 3     (Price, 42608217.31578516)  (Floor_Area, 120.35088109852998)
# Cluster 4     (Price, 44388417.31578516)  (Floor_Area, 153.22521443186332)
# ...                                  ...                               ...
# Cluster 636   (Price, 42327167.31578516)  (Floor_Area, 152.79354776519665)
# Cluster 637   (Price, 40680509.06578516)  (Floor_Area, 163.84354776519666)
# Cluster 638   (Price, 42698975.72487607)  (Floor_Area, 190.86172958337846)
# Cluster 639   (Price, 45664667.31578516)  (Floor_Area, 210.79354776519665)
# Cluster 640   (Price, 42622306.20467405)   (Floor_Area, 187.5991033207522)
#
#                                 Top Feature 3
# Cluster 0     (Land_Area, 151.16676514815532)
# Cluster 1    (Floor_Area, 116.04354776519665)
# Cluster 2     (Land_Area, 151.09948940064703)
# Cluster 3      (Land_Area, 115.7196798768375)
# Cluster 4     (Land_Area, 141.61901321017086)
# ...                                       ...
# Cluster 636   (Land_Area, 124.65234654350418)
# Cluster 637   (Land_Area, 129.07734654350418)
# Cluster 638   (Land_Area, 138.20234654350418)
# Cluster 639   (Land_Area, 164.57734654350418)
# Cluster 640   (Land_Area, 120.73012432128195)
#
# [641 rows x 3 columns]

# %% [markdown]
# ### Condo

# %%
find_optimal_clusters(X_condo, max_clusters=10)
# Out:
# Optimal number of clusters: 3
# 3

# %%
optimal_clusters = 3
# K-Means Pipeline
kmeans_pipeline = make_pipeline(StandardScaler(), KMeans(n_clusters=optimal_clusters, random_state=42))

# BIRCH Pipeline
birch_pipeline = make_pipeline(StandardScaler(), Birch(n_clusters=optimal_clusters))

# DBSCAN Pipeline (corrected)
dbscan_pipeline = make_pipeline(StandardScaler(), DBSCAN(eps=0.5, min_samples=5))

kmeans_labels = kmeans_pipeline.fit_predict(X_condo)
birch_labels = birch_pipeline.fit_predict(X_condo)
dbscan_labels = dbscan_pipeline.fit_predict(X_condo)

# %%
# Create copies for each clustering method
x_kmeans = X_condo.copy()
x_birch = X_condo.copy()
x_dbscan = X_condo.copy()

# Add cluster labels
x_kmeans["Cluster"] = kmeans_labels
x_birch["Cluster"] = birch_labels
x_dbscan["Cluster"] = dbscan_labels

# Save each dataset as a separate CSV file
x_kmeans.to_csv("condo_kmeans.csv", index=False)
x_birch.to_csv("condo_birch.csv", index=False)
x_dbscan.to_csv("condo_dbscan.csv", index=False)

# %%
# Example usage:
kmeans_silhouette = get_silhouette_score(kmeans_pipeline, X_condo)
birch_silhouette = get_silhouette_score(birch_pipeline, X_condo)
dbscan_silhouette = get_silhouette_score(dbscan_pipeline, X_condo)

print("K-Means Silhouette Score:", kmeans_silhouette)
print("BIRCH Silhouette Score:", birch_silhouette)
print("DBSCAN Silhouette Score:", dbscan_silhouette)
# Out:
# K-Means Silhouette Score: -0.18384339302656483
# BIRCH Silhouette Score: -0.38983560766763725
# DBSCAN Silhouette Score: -0.844636044823669

# %%
# Example usage:
kmeans_features = get_top_features(kmeans_pipeline, X_condo)
birch_features = get_top_features(birch_pipeline, X_condo)
dbscan_features = get_top_features(dbscan_pipeline, X_condo)

print("K-Means Top Features:\n", kmeans_features)
print("\nBIRCH Top Features:\n", birch_features)
print("\nDBSCAN Top Features:\n", dbscan_features)  # Now correctly calculates top features!
# Out:
# K-Means Top Features:
#                               Top Feature 1  \
# Cluster 0   (ATMCount, 1.0989796215463217)
# Cluster 1  (ATMCount, -0.4771470940889804)
# Cluster 2  (MallCount, 0.7568506030061178)
#
#                                                Top Feature 2  \
# Cluster 0  (presence_of_business_and_professional_organiz...
# Cluster 1                   (MallCount, -0.5317387354553016)
# Cluster 2        (employment_generation, 1.2635169079079385)
#
#                                         Top Feature 3
# Cluster 0  (local_economy_growth, 1.9997690875343646)
# Cluster 1   (local_economy_size, -0.5792836918512709)
# Cluster 2    (local_economy_size, 1.4972856986532628)
#
# BIRCH Top Features:
#                                              Top Feature 1  \
# Cluster 0              (Num_Bedrooms, 1.6327550088955063)
# Cluster 1              (Num_Bedrooms, 1.6327550088955063)
# Cluster 2               (SchoolCount, 1.1449145630613364)
# Cluster 3             (Num_Bathrooms, 1.7501154228118978)
# Cluster 4       (local_economy_size, -1.3022636165925794)
# ...                                                   ...
# Cluster 1462               (BusCount, -1.338676315616833)
# Cluster 1463           (SchoolCount, -1.6665108121409902)
# Cluster 1464    (local_economy_size, -1.2850349624975417)
# Cluster 1465            (Num_Bedrooms, 2.342012880303626)
# Cluster 1466  (local_economy_growth, -1.2994154453630204)
#
#                                             Top Feature 2  \
# Cluster 0                (Num_Bathrooms, 2.4424937796927)
# Cluster 1              (Num_Bathrooms, 3.134872136573503)
# Cluster 2        (local_economy_size, 1.4336056330944273)
# Cluster 3               (Num_Bedrooms, 5.179044365936106)
# Cluster 4             (HospitalCount, 2.7271048820034673)
# ...                                                   ...
# Cluster 1462   (local_economy_growth, -1.348263338429332)
# Cluster 1463          (Num_Bathrooms, 1.7501154228118978)
# Cluster 1464  (local_economy_growth, -1.2994154453630207)
# Cluster 1465             (Num_Bathrooms, 2.4424937796927)
# Cluster 1466           (Num_Bedrooms, 1.6327550088955063)
#
#                                   Top Feature 3
# Cluster 0       (Floor_Area, 9.714836918958861)
# Cluster 1       (Floor_Area, 8.832949358787229)
# Cluster 2      (Floor_Area, 131.59875283515981)
# Cluster 3       (Floor_Area, 78.09287078442654)
# Cluster 4     (Num_Bedrooms, 7.306817980160465)
# ...                                         ...
# Cluster 1462   (LRTHubDist, 4.7963252894200785)
# Cluster 1463    (LRTHubDist, 6.381480402563836)
# Cluster 1464   (LRTHubDist, 7.2121960686160085)
# Cluster 1465    (LRTHubDist, 6.655163945031288)
# Cluster 1466    (LRTHubDist, 7.230332422713797)
#
# [1467 rows x 3 columns]
#
# DBSCAN Top Features:
#                             Top Feature 1                      Top Feature 2  \
# Cluster 0    (Price, 10629858.771174721)    (Floor_Area, 8.677168781632801)
# Cluster 1    (Price, 14301148.771174721)     (Floor_Area, 24.0103312183672)
# Cluster 2     (Price, 18668687.93784139)   (Floor_Area, 57.310331218367196)
# Cluster 3    (Price, 18679470.485460434)   (Floor_Area, 47.896045504081485)
# Cluster 4    (Price, 19383977.342603292)    (Floor_Area, 55.83604550408149)
# ...                                  ...                                ...
# Cluster 644   (Price, 8878108.771174721)     (Floor_Area, 18.7103312183672)
# Cluster 645  (Price, 3084113.4510475025)  (SchoolCount, 7.9230176776938315)
# Cluster 646  (Price, 2321891.2288252786)   (Floor_Area, 10.403002114966128)
# Cluster 647  (Price, 18101871.534508053)     (Floor_Area, 51.5003312183672)
# Cluster 648   (Price, 20628408.77117472)     (Floor_Area, 62.2603312183672)
#
#                                  Top Feature 3
# Cluster 0    (HospitalCount, 8.62018631262378)
# Cluster 1    (HospitalCount, 8.62018631262378)
# Cluster 2       (ATMCount, 10.457309469669184)
# Cluster 3       (ATMCount, 18.457309469669184)
# Cluster 4       (ATMCount, 18.457309469669184)
# ...                                        ...
# Cluster 644      (ATMCount, 8.057309469669184)
# Cluster 645      (BusCount, 6.201019584830924)
# Cluster 646     (ATMCount, 10.323976136335851)
# Cluster 647     (ATMCount, 15.790642803002518)
# Cluster 648     (ATMCount, 16.457309469669184)
#
# [649 rows x 3 columns]

# %% [markdown]
# ### Apt

# %%
find_optimal_clusters(X_apt, max_clusters=10)
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Optimal number of clusters: 4
# 4

# %%
optimal_clusters = 4

# K-Means Pipeline
kmeans_pipeline = make_pipeline(StandardScaler(), KMeans(n_clusters=optimal_clusters, random_state=42))

# BIRCH Pipeline
birch_pipeline = make_pipeline(StandardScaler(), Birch(n_clusters=optimal_clusters))

# DBSCAN Pipeline (corrected)
dbscan_pipeline = make_pipeline(StandardScaler(), DBSCAN(eps=0.5, min_samples=5))

kmeans_labels = kmeans_pipeline.fit_predict(X_apt)
birch_labels = birch_pipeline.fit_predict(X_apt)
dbscan_labels = dbscan_pipeline.fit_predict(X_apt)
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
# Create copies for each clustering method
x_kmeans = X_apt.copy()
x_birch = X_apt.copy()
x_dbscan = X_apt.copy()

# Add cluster labels
x_kmeans["Cluster"] = kmeans_labels
x_birch["Cluster"] = birch_labels
x_dbscan["Cluster"] = dbscan_labels

# Save each dataset as a separate CSV file
x_kmeans.to_csv("apt_kmeans.csv", index=False)
x_birch.to_csv("apt_birch.csv", index=False)
x_dbscan.to_csv("apt_dbscan.csv", index=False)

# %%
# Example usage:
kmeans_silhouette = get_silhouette_score(kmeans_pipeline, X_apt)
birch_silhouette = get_silhouette_score(birch_pipeline, X_apt)
dbscan_silhouette = get_silhouette_score(dbscan_pipeline, X_apt)

print("K-Means Silhouette Score:", kmeans_silhouette)
print("BIRCH Silhouette Score:", birch_silhouette)
print("DBSCAN Silhouette Score:", dbscan_silhouette)
# Out:
# K-Means Silhouette Score: -0.2417181683667499
# BIRCH Silhouette Score: -0.057083308680891474
# DBSCAN Silhouette Score: -0.6232253260452328

# %%
# Example usage:
kmeans_features = get_top_features(kmeans_pipeline, X_apt)
birch_features = get_top_features(birch_pipeline, X_apt)
dbscan_features = get_top_features(dbscan_pipeline, X_apt)

print("K-Means Top Features:\n", kmeans_features)
print("\nBIRCH Top Features:\n", birch_features)
print("\nDBSCAN Top Features:\n", dbscan_features)  # Now correctly calculates top features!
# Out:
# K-Means Top Features:
#                                                 Top Feature 1  \
# Cluster 0                    (MallCount, 0.8358779037361415)
# Cluster 1  (presence_of_business_and_professional_organiz...
# Cluster 2   (safety_compliant_business, -0.6473861361553201)
# Cluster 3    (safety_compliant_business, 0.6952618194432683)
#
#                                                Top Feature 2  \
# Cluster 0        (employment_generation, 1.2700837972251442)
# Cluster 1                     (BusCount, 1.7982612818376105)
# Cluster 2                 (SchoolCount, -0.6679579207370027)
# Cluster 3  (presence_of_business_and_professional_organiz...
#
#                                           Top Feature 3
# Cluster 0      (local_economy_size, 1.7245812116662373)
# Cluster 1            (HospitalCount, 2.779127915870746)
# Cluster 2  (employment_generation, -0.6819118748889424)
# Cluster 3    (local_economy_growth, 1.1177865806279248)
#
# BIRCH Top Features:
#                                             Top Feature 1  \
# Cluster 0                (LRTHubDist, 7.690125606107509)
# Cluster 1                (BusCount, -1.0830438242965765)
# Cluster 2    (local_economy_growth, -1.3913688021835364)
# Cluster 3    (local_economy_growth, -1.3846361796042002)
# Cluster 4               (LRTHubDist, 1.6445728868641378)
# ...                                                  ...
# Cluster 178             (Floor_Area, 4.1972862568763025)
# Cluster 179              (MallCount, 2.5892153946130727)
# Cluster 180                  (Price, 2.3402502295339715)
# Cluster 181           (Num_Bedrooms, 1.9580405284051048)
# Cluster 182  (employment_generation, 3.2104567480459556)
#
#                                                Top Feature 2  \
# Cluster 0                    (Floor_Area, 8.826750491790705)
# Cluster 1                 (SchoolCount, -1.1566569776063116)
# Cluster 2    (safety_compliant_business, 2.1602549992578575)
# Cluster 3                 (SchoolCount, -1.4331994244740418)
# Cluster 4                 (SchoolCount, -1.7788774830587042)
# ...                                                      ...
# Cluster 178                       (Price, 4.858589056147006)
# Cluster 179                       (Price, 4.019142780609328)
# Cluster 180                  (MallCount, 2.5892153946130727)
# Cluster 181                 (Floor_Area, 4.1972862568763025)
# Cluster 182                  (Floor_Area, 5.015668857124566)
#
#                                                Top Feature 3
# Cluster 0                (Num_Bathrooms, 11.155198480016692)
# Cluster 1                   (LRTHubDist, 1.4122064101999343)
# Cluster 2                    (LRTHubDist, 2.603563377644836)
# Cluster 3                    (LRTHubDist, 3.662885199481056)
# Cluster 4    (safety_compliant_business, 2.1602549992578575)
# ...                                                      ...
# Cluster 178               (Num_Bathrooms, 5.140199562607106)
# Cluster 179                  (Floor_Area, 4.901120456181164)
# Cluster 180                  (Floor_Area, 4.599726712715326)
# Cluster 181                       (Price, 4.858589056147006)
# Cluster 182                (Num_Bedrooms, 11.57571222310534)
#
# [183 rows x 3 columns]
#
# DBSCAN Top Features:
#                           Top Feature 1                     Top Feature 2  \
# Cluster 0   (Price, 63815008.30592105)  (Floor_Area, 235.05200657894738)
# Cluster 1    (Price, 44788563.8614766)    (Floor_Area, 448.718673245614)
# Cluster 2  (Price, 46429294.020206764)   (Floor_Area, 423.7662922932331)
# Cluster 3   (Price, 46384991.69407895)  (Floor_Area, 242.63399342105265)
#
#                             Top Feature 3
# Cluster 0   (BusCount, 16.56907894736842)
# Cluster 1  (BusCount, 41.430921052631575)
# Cluster 2  (BusCount, 20.288063909774433)
# Cluster 3  (BusCount, 13.569078947368421)

# %% [markdown]
# ### Commercial Real Estate

# %%
find_optimal_clusters(X_com, max_clusters=10)
# Out:
# Optimal number of clusters: 3
# 3

# %%
optimal_clusters = 3

# K-Means Pipeline
kmeans_pipeline = make_pipeline(StandardScaler(), KMeans(n_clusters=optimal_clusters, random_state=42))

# BIRCH Pipeline
birch_pipeline = make_pipeline(StandardScaler(), Birch(n_clusters=optimal_clusters))

# DBSCAN Pipeline (corrected)
dbscan_pipeline = make_pipeline(StandardScaler(), DBSCAN(eps=0.5, min_samples=5))

kmeans_labels = kmeans_pipeline.fit_predict(X_com)
birch_labels = birch_pipeline.fit_predict(X_com)
dbscan_labels = dbscan_pipeline.fit_predict(X_com)

# %%
# Create copies for each clustering method
x_kmeans = X_com.copy()
x_birch = X_com.copy()
x_dbscan = X_com.copy()

# Add cluster labels
x_kmeans["Cluster"] = kmeans_labels
x_birch["Cluster"] = birch_labels
x_dbscan["Cluster"] = dbscan_labels

# Save each dataset as a separate CSV file
x_kmeans.to_csv("com_kmeans.csv", index=False)
x_birch.to_csv("com_birch.csv", index=False)
x_dbscan.to_csv("com_dbscan.csv", index=False)

# %%
# Example usage:
kmeans_silhouette = get_silhouette_score(kmeans_pipeline, X_com)
birch_silhouette = get_silhouette_score(birch_pipeline, X_com)
dbscan_silhouette = get_silhouette_score(dbscan_pipeline, X_com)

print("K-Means Silhouette Score:", kmeans_silhouette)
print("BIRCH Silhouette Score:", birch_silhouette)
print("DBSCAN Silhouette Score:", dbscan_silhouette)
# Out:
# K-Means Silhouette Score: -0.05784866714317706
# BIRCH Silhouette Score: 0.834240487965462
# DBSCAN Silhouette Score: -0.7639266661521096

# %%
# Example usage:
kmeans_features = get_top_features(kmeans_pipeline, X_com)
birch_features = get_top_features(birch_pipeline, X_com)
dbscan_features = get_top_features(dbscan_pipeline, X_com)

print("K-Means Top Features:\n", kmeans_features)
print("\nBIRCH Top Features:\n", birch_features)
print("\nDBSCAN Top Features:\n", dbscan_features)  # Now correctly calculates top features!
# Out:
# K-Means Top Features:
#                                                 Top Feature 1  \
# Cluster 0          (local_economy_size, -0.5209392811991913)
# Cluster 1  (presence_of_business_and_professional_organiz...
# Cluster 2  (presence_of_business_and_professional_organiz...
#
#                                         Top Feature 2  \
# Cluster 0  (local_economy_growth, 0.5896362145552874)
# Cluster 1          (SchoolCount, -0.7786006295855337)
# Cluster 2  (employment_generation, 1.116712701923367)
#
#                                                Top Feature 3
# Cluster 0  (presence_of_business_and_professional_organiz...
# Cluster 1       (employment_generation, -0.9402011090558302)
# Cluster 2            (local_economy_size, 1.556456088035282)
#
# BIRCH Top Features:
#                                            Top Feature 1  \
# Cluster 0               (LRTHubDist, 3.839371016137047)
# Cluster 1                    (Price, 3.202758035943216)
# Cluster 2                    (Price, 3.202758035943216)
# Cluster 3               (BusCount, -1.4429279796213677)
# Cluster 4            (SchoolCount, -1.7478602307948563)
# ...                                                 ...
# Cluster 447    (local_economy_size, 1.4681178698381958)
# Cluster 448             (Land_Area, 1.6510648514433148)
# Cluster 449  (employment_generation, 3.216068353089836)
# Cluster 450  (employment_generation, 3.216068353089836)
# Cluster 451           (SchoolCount, 1.7935566160711642)
#
#                                                  Top Feature 2  \
# Cluster 0                      (Floor_Area, 6.737621897313024)
# Cluster 1                     (LRTHubDist, 3.3842048539758496)
# Cluster 2                     (LRTHubDist, 3.3842048539758496)
# Cluster 3                      (Floor_Area, 4.908371791592579)
# Cluster 4      (safety_compliant_business, 2.1411101838024353)
# ...                                                        ...
# Cluster 447                   (Floor_Area, 12.056520165045592)
# Cluster 448  (presence_of_business_and_professional_organiz...
# Cluster 449                    (Floor_Area, 8.083173897599842)
# Cluster 450                   (Floor_Area, 6.5570864133097375)
# Cluster 451                    (Floor_Area, 9.494971167626618)
#
#                                 Top Feature 3
# Cluster 0     (Land_Area, 20.359989976798218)
# Cluster 1      (Land_Area, 12.69056044143724)
# Cluster 2      (Land_Area, 12.69056044143724)
# Cluster 3      (Land_Area, 30.49503702139483)
# Cluster 4     (LRTHubDist, 3.298565596667742)
# ...                                       ...
# Cluster 447       (Price, 20.433000691500112)
# Cluster 448  (Floor_Area, 13.453434265903317)
# Cluster 449        (Price, 8.252335741114056)
# Cluster 450       (Price, 10.743835390056658)
# Cluster 451        (Price, 19.04883421986533)
#
# [452 rows x 3 columns]
#
# DBSCAN Top Features:
#                             Top Feature 1                     Top Feature 2  \
# Cluster 0      (Price, 85166204.9495984)   (Land_Area, 2184.5349624573378)
# Cluster 1    (Price, 183876788.28293175)  (Floor_Area, 1432.6076962457337)
# Cluster 2    (Price, 205843188.28293175)  (Floor_Area, 1474.6076962457337)
# Cluster 3    (Price, 33267413.282931745)  (Floor_Area, 1494.6076962457337)
# Cluster 4     (Price, 87421788.28293175)   (Land_Area, 3905.4099624573378)
# ...                                  ...                               ...
# Cluster 102    (Price, 161332502.568646)  (Floor_Area, 1310.2048391028766)
# Cluster 103  (Price, 177446788.28293175)  (Floor_Area, 1302.1196962457336)
# Cluster 104  (Price, 164852183.71706825)    (Land_Area, 8813.334962457337)
# Cluster 105  (Price, 154901988.28293175)   (Floor_Area, 359.1076962457337)
# Cluster 106   (Price, 178523454.9495984)    (Land_Area, 564.2983708759955)
#
#                                 Top Feature 3
# Cluster 0    (Floor_Area, 1746.3923037542663)
# Cluster 1      (Land_Area, 303.1349624573378)
# Cluster 2     (Land_Area, 398.66503754266216)
# Cluster 3      (Land_Area, 526.7849624573379)
# Cluster 4    (Floor_Area, 2005.6110537542663)
# ...                                       ...
# Cluster 102    (Land_Area, 896.0364661140907)
# Cluster 103    (Land_Area, 988.4650375426621)
# Cluster 104   (Floor_Area, 4981.392303754266)
# Cluster 105   (Land_Area, 115.63496245733779)
# Cluster 106   (Floor_Area, 547.1076962457337)
#
# [107 rows x 3 columns]

# %% [markdown]
# ### Land

# %%
find_optimal_clusters(X_land, max_clusters=10)
# Out:
# Optimal number of clusters: 2
# 2

# %%
optimal_clusters = 2

# K-Means Pipeline
kmeans_pipeline = make_pipeline(StandardScaler(), KMeans(n_clusters=optimal_clusters, random_state=42))

# BIRCH Pipeline
birch_pipeline = make_pipeline(StandardScaler(), Birch(n_clusters=optimal_clusters))

# DBSCAN Pipeline (corrected)
dbscan_pipeline = make_pipeline(StandardScaler(), DBSCAN(eps=0.5, min_samples=5))

kmeans_labels = kmeans_pipeline.fit_predict(X_land)
birch_labels = birch_pipeline.fit_predict(X_land)
dbscan_labels = dbscan_pipeline.fit_predict(X_land)

# %%
# Create copies for each clustering method
x_kmeans = X_land.copy()
x_birch = X_land.copy()
x_dbscan = X_land.copy()

# Add cluster labels
x_kmeans["Cluster"] = kmeans_labels
x_birch["Cluster"] = birch_labels
x_dbscan["Cluster"] = dbscan_labels

# Save each dataset as a separate CSV file
x_kmeans.to_csv("land_kmeans.csv", index=False)
x_birch.to_csv("land_birch.csv", index=False)
x_dbscan.to_csv("land_dbscan.csv", index=False)

# %%
# Example usage:
kmeans_silhouette = get_silhouette_score(kmeans_pipeline, X_land)
birch_silhouette = get_silhouette_score(birch_pipeline, X_land)
dbscan_silhouette = get_silhouette_score(dbscan_pipeline, X_land)

print("K-Means Silhouette Score:", kmeans_silhouette)
print("BIRCH Silhouette Score:", birch_silhouette)
print("DBSCAN Silhouette Score:", dbscan_silhouette)
# Out:
# K-Means Silhouette Score: -0.04787069856309641
# BIRCH Silhouette Score: 0.9987575081806185
# DBSCAN Silhouette Score: -0.8276138216580713

# %%
# Example usage:
kmeans_features = get_top_features(kmeans_pipeline, X_land)
birch_features = get_top_features(birch_pipeline, X_land)
dbscan_features = get_top_features(dbscan_pipeline, X_land)

print("K-Means Top Features:\n", kmeans_features)
print("\nBIRCH Top Features:\n", birch_features)
print("\nDBSCAN Top Features:\n", dbscan_features)  # Now correctly calculates top features!
# Out:
# K-Means Top Features:
#                                            Top Feature 1  \
# Cluster 0  (employment_generation, -0.4771162645146519)
# Cluster 1   (employment_generation, 0.8548263343180665)
#
#                                                Top Feature 2  \
# Cluster 0  (presence_of_business_and_professional_organiz...
# Cluster 1  (presence_of_business_and_professional_organiz...
#
#                                          Top Feature 3
# Cluster 0  (local_economy_growth, -0.5453658090622806)
# Cluster 1   (local_economy_growth, 0.9771057708488619)
#
# BIRCH Top Features:
#                                                  Top Feature 1  \
# Cluster 0    (safety_compliant_business, -1.2258383702870994)
# Cluster 1           (local_economy_size, -0.8514820050157057)
# Cluster 2           (local_economy_size, -0.8514820050157057)
# Cluster 3        (employment_generation, -0.8731534821969908)
# Cluster 4           (local_economy_size, -0.9065784675130429)
# ...                                                       ...
# Cluster 401        (local_economy_growth, 1.3747136888364928)
# Cluster 402   (safety_compliant_business, 1.1500829434274549)
# Cluster 403        (local_economy_growth, 1.3747136888364928)
# Cluster 404        (local_economy_growth, 1.3747136888364928)
# Cluster 405                      (BusCount, 2.11565491560914)
#
#                                                 Top Feature 2  \
# Cluster 0        (employment_generation, -1.2640439099265197)
# Cluster 1                     (MallCount, 0.9044906291879452)
# Cluster 2         (employment_generation, -0.928390091137599)
# Cluster 3    (safety_compliant_business, -0.9035481997582833)
# Cluster 4        (employment_generation, -1.3166502041556698)
# ...                                                       ...
# Cluster 401                    (BusCount, 2.2121085946562777)
# Cluster 402        (local_economy_growth, 1.3747136888364928)
# Cluster 403                    (BusCount, 1.8262938784677263)
# Cluster 404                        (Price, 3.538876608264125)
# Cluster 405                (HospitalCount, 2.938618203729463)
#
#                                                 Top Feature 3
# Cluster 0                   (Num_Bedrooms, 89.20762299265687)
# Cluster 1         (employment_generation, -0.928390091137599)
# Cluster 2                 (HospitalCount, 1.4719197599817178)
# Cluster 3         (local_economy_growth, -0.9325055084692321)
# Cluster 4    (safety_compliant_business, -1.4533104991327563)
# ...                                                       ...
# Cluster 401                (HospitalCount, 8.316512497471196)
# Cluster 402                (HospitalCount, 3.427517684978712)
# Cluster 403                (HospitalCount, 4.405316647477209)
# Cluster 404                (HospitalCount, 4.894216128726457)
# Cluster 405       (employment_generation, 3.5446846147566498)
#
# [406 rows x 3 columns]
#
# DBSCAN Top Features:
#                             Top Feature 1                    Top Feature 2  \
# Cluster 0    (Price, 304731626.48215353)   (Land_Area, 24615.81085174017)
# Cluster 1    (Price, 233037321.72024876)  (Land_Area, 25898.000375549695)
# Cluster 2    (Price, 255349721.72024876)  (Land_Area, 26020.820375549694)
# Cluster 3     (Price, 113442055.0535821)  (Land_Area, 26098.620375549694)
# Cluster 4     (Price, 27488278.27975124)  (Land_Area, 24366.220375549692)
# ...                                  ...                              ...
# Cluster 230  (Price, 250052721.72024876)   (Land_Area, 23525.33466126398)
# Cluster 231  (Price, 165097959.65128323)  (Land_Area, 19842.606582446246)
# Cluster 232  (Price, 274053721.72024876)  (Land_Area, 25394.220375549692)
# Cluster 233  (Price, 444920610.42260844)   (Land_Area, 4771.802518406836)
# Cluster 234  (Price, 329602521.72024876)  (Land_Area, 26606.020375549695)
#
#                                 Top Feature 3
# Cluster 0    (Floor_Area, 13.326925493152405)
# Cluster 1    (Floor_Area, 13.326925493152405)
# Cluster 2    (Floor_Area, 13.326925493152405)
# Cluster 3    (Floor_Area, 13.326925493152405)
# Cluster 4    (Floor_Area, 13.326925493152405)
# ...                                       ...
# Cluster 230  (Floor_Area, 13.326925493152405)
# Cluster 231  (Floor_Area, 13.326925493152405)
# Cluster 232  (Floor_Area, 13.326925493152405)
# Cluster 233  (Floor_Area, 13.326925493152405)
# Cluster 234  (Floor_Area, 13.326925493152405)
#
# [235 rows x 3 columns]
