# %%
import numpy as np
import pandas as pd

# %%
house_cluster = pd.read_csv('house_tuned_dbscan.csv')
condo_cluster = pd.read_csv('condo_kmeans.csv')
apt_cluster = pd.read_csv('apt_tuned_dbscan.csv')
com_cluster = pd.read_csv('com_tuned_dbscan.csv')
land_cluster = pd.read_csv('land_birch.csv')

# %%
house_cluster_means = house_cluster.groupby("DBSCAN_Cluster").mean()
print(house_cluster_means)
# Out:
#                        Price  Num_Bedrooms  Num_Bathrooms   Floor_Area  \
# DBSCAN_Cluster
# -1              5.998490e+08      9.695652      77.873913  1582.313826
#  0              4.880765e+07      3.828304       3.614162   277.206252
#  1              5.190089e+07      3.866093       3.920147   307.310147
#
#                   Land_Area  LRTHubDist   BusCount  MallCount  SchoolCount  \
# DBSCAN_Cluster
# -1              1500.722435    9.981386  12.956522   3.060870     9.217391
#  0               215.135924    7.150175   9.833464   0.657516    10.680035
#  1               166.577420    5.015056  10.459459   0.847666    20.670762
#
#                 HospitalCount   ATMCount  employment_generation  \
# DBSCAN_Cluster
# -1                   0.904348  19.226087               0.696155
#  0                   1.536957   3.803136               0.640858
#  1                   0.749386  13.904177               0.084100
#
#                 local_economy_growth  local_economy_size  \
# ...

# %%
condo_cluster_means = condo_cluster.groupby("Cluster").mean()
print(condo_cluster_means)
# Out:
#                 Price  Num_Bedrooms  Num_Bathrooms  Floor_Area  Land_Area  \
# Cluster
# 0        1.549145e+07      1.573227       1.343875   68.785057        0.0
# 1        2.022978e+07      1.692223       1.447021   77.891959        0.0
# 2        3.086282e+07      1.763472       1.581487  103.653689        0.0
#
#          LRTHubDist   BusCount  MallCount  SchoolCount  HospitalCount  \
# Cluster
# 0          6.158631  14.010132   5.402211    12.192815       0.943813
# 1          6.618619  14.879502   1.428885     9.093761       1.794347
# 2          2.916738  22.112757   4.999476    11.285302       0.675626
#
#           ATMCount  employment_generation  local_economy_growth  \
# Cluster
# 0        38.638010               0.180112              0.884865
# 1         9.695397               0.349680              0.314362
# 2        28.659106               1.135443              0.222293
#
#          local_economy_size  \
# Cluster
# 0                  0.386322
# ...

# %%
apt_cluster_means = apt_cluster.groupby("DBSCAN_Cluster").mean()
print(apt_cluster_means)
# Out:
#                        Price  Num_Bedrooms  Num_Bathrooms   Floor_Area  \
# DBSCAN_Cluster
# -1              2.195293e+08     45.294118      18.529412  2081.739412
#  0              5.195871e+07     10.903846       6.298077   472.948731
#  1              6.761000e+07      9.800000       5.900000   630.200000
#
#                 Land_Area  LRTHubDist   BusCount  MallCount  SchoolCount  \
# DBSCAN_Cluster
# -1                    0.0    7.329542  19.058824   3.235294    12.264706
#  0                    0.0    4.273426  16.538462   1.161538    13.180769
#  1                    0.0    4.593677   8.900000   0.400000    21.900000
#
#                 HospitalCount   ATMCount  employment_generation  \
# DBSCAN_Cluster
# -1                   1.029412  18.823529               0.996697
#  0                   2.565385   6.553846               0.573600
#  1                   0.400000  10.600000               0.084100
#
#                 local_economy_growth  local_economy_size  \
# ...

# %%
com_cluster_means = com_cluster.groupby("DBSCAN_Cluster").mean()
print(com_cluster_means)
# Out:
#                        Price  Num_Bedrooms  Num_Bathrooms    Floor_Area  \
# DBSCAN_Cluster
# -1              5.048467e+09     12.764706       1.941176  46884.932353
#  0              2.069431e+08      0.000344       0.000344   1221.092025
#  1              2.413925e+09      0.000000       0.000000   7500.000000
#
#                    Land_Area  LRTHubDist   BusCount  MallCount  SchoolCount  \
# DBSCAN_Cluster
# -1              15084.176471    6.434685  21.117647   3.294118     9.705882
#  0                839.346016    5.005088  18.247508   2.992437    11.465796
#  1              49528.500000   21.351382  14.000000   0.750000     9.500000
#
#                 HospitalCount   ATMCount  employment_generation  \
# DBSCAN_Cluster
# -1                   1.294118  19.941176               0.884524
#  0                   1.906841  17.511172               0.641830
#  1                   1.000000   1.000000               0.728975
#
#                 local_economy_growth  local_economy_size  \
# ...

# %%
land_cluster_means = land_cluster.groupby("Cluster").mean()
print(land_cluster_means)
# Out:
#                 Price  Num_Bedrooms  Num_Bathrooms  Floor_Area     Land_Area  \
# Cluster
# 0        2.276171e+08      0.000251            0.0   13.330275  7.997016e+03
# 1        4.300000e+11      0.000000            0.0    0.000000  7.500010e+07
#
#          LRTHubDist  BusCount  MallCount  SchoolCount  HospitalCount  \
# Cluster
# 0         13.633115  8.065351   0.700013     6.801056       0.989569
# 1         18.927459  9.000000   1.000000     5.500000       0.000000
#
#          ATMCount  employment_generation  local_economy_growth  \
# Cluster
# 0        4.025512               0.527286              0.206981
# 1        5.000000               0.111300              0.175050
#
#          local_economy_size  \
# Cluster
# 0                  0.395532
# 1                  0.255050
#
#          presence_of_business_and_professional_organizations  \
# Cluster
# 0                                                 0.078688
# 1                                                 0.013100
#
# ...
