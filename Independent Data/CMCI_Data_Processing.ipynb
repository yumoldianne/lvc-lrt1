# %% [markdown]
# Typically 3,5,6,7,9 have <10 VIF
#
# 0	active_establishments_in_the_locality
# 1	cost_of_doing_business
# 2	cost_of_living
# 3	employment_generation
# 4	financial_deepening
# 5	local_economy_growth
# 6	local_economy_size
# 7	presence_of_business_and_professional_organiza...
# 8	productivity
# 9	safety_compliant_business

# %%
import pandas as pd
import numpy as np
import os

def csvs_to_dfs(directory):
    dataframes = {}
    global_names = []

    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            filepath = os.path.join(directory, filename)
            df_name = os.path.splitext(filename)[0].lower().replace(" ", "_")
            
            global_names.append(df_name)
            
            df = pd.read_csv(filepath)
            dataframes[df_name] = df
            print(f"Successfully read: {filename}")
    print("\n")
    
    if global_names:
        for name in global_names:
            print(name)
    
    return global_names, dataframes

df_names, dataframes = csvs_to_dfs(os.getcwd())
# Out:
# Successfully read: Active Establishments in the Locality.csv
# Successfully read: CMCI_2023_Full.csv
# Successfully read: CMCI_2023_Shortlist.csv
# Successfully read: Cost of Doing Business.csv
# Successfully read: Cost of Living.csv
# Successfully read: Employment Generation.csv
# Successfully read: Financial Deepening.csv
# Successfully read: Local Economy Growth.csv
# Successfully read: Local Economy Size.csv
# Successfully read: Presence of Business and Professional Organizations.csv
# Successfully read: Productivity.csv
# Successfully read: Safety Compliant Business.csv
#
#
# active_establishments_in_the_locality
# cmci_2023_full
# cmci_2023_shortlist
# cost_of_doing_business
# cost_of_living
# employment_generation
# financial_deepening
# local_economy_growth
# local_economy_size
# presence_of_business_and_professional_organizations
# productivity
# safety_compliant_business

# %%
# SAMPLE
dataframes['active_establishments_in_the_locality'].head()
# Out:
#   PROVINCE / LGU 2014 2015 2016    2017    2018    2019    2020    2021  \
# 0    Quezon (MM)    -    -    -  0.9163  2.5000  2.2849  2.5000  2.5000
# 1       Caloocan    -    -    -  0.2244  0.3661  0.3552  0.5003  0.4275
# 2         Manila    -    -    -  1.6315  1.9449  2.2725  2.5000  1.8303
# 3          Pasay    -    -    -  0.1937  0.3809  0.3991  0.7650  0.5448
# 4      Paranaque    -    -    -  0.0000  0.6105  0.5298  0.9811  0.6202
#
#      2022    2023
# 0  1.9815  1.7600
# 1  0.4411  0.3098
# 2  1.5532  0.0000
# 3  0.4364  0.0000
# 4  0.5063  0.5142

# %%
def concat_year(year, df_names, dataframes):
    selected_dfs = []
    
    for name in df_names:
        df = dataframes[name]
        if year in df.columns:
            selected_df = df[["PROVINCE / LGU", year]].copy()
            selected_df.columns = ["PROVINCE / LGU", name]
            selected_dfs.append(selected_df.set_index("PROVINCE / LGU"))
    
    if selected_dfs:
        result_df = pd.concat(selected_dfs, axis=1)
        return result_df
    else:
        print("No valid data found for the specified year.")
        return None

df_2023 = concat_year('2023', df_names, dataframes)
# df_2023.to_csv("CMCI_2023_Full.csv", encoding="utf-8-sig")
df_2023.head()
# Out:
#                 active_establishments_in_the_locality  cost_of_doing_business  \
# PROVINCE / LGU
# Quezon (MM)                                    1.7600                  1.4609
# Caloocan                                       0.3098                  1.3764
# Manila                                         0.0000                  1.2995
# Pasay                                          0.0000                  1.4822
# Paranaque                                      0.5142                  1.4267
#
#                 cost_of_living  employment_generation  financial_deepening  \
# PROVINCE / LGU
# Quezon (MM)             0.7925                 0.9248               1.3115
# Caloocan                0.7925                 0.1654               0.4734
# Manila                  0.7925                 0.4600               1.1539
# Pasay                   0.7925                 2.0000               0.5909
# Paranaque               0.7925                 0.7071               0.3316
#
#                 local_economy_growth  local_economy_size  \
# PROVINCE / LGU
# Quezon (MM)                   0.5111              0.4807
# Caloocan                      0.3167              0.0555
# Manila                        0.3905              0.3591
# Pasay                         0.2022              2.0000
# Paranaque                     0.2952              0.3623
#
#                 presence_of_business_and_professional_organizations  \
# PROVINCE / LGU
# Quezon (MM)                                                0.1880
# Caloocan                                                   0.0567
# Manila                                                     0.3590
# Pasay                                                      0.1095
# Paranaque                                                  0.0081
#
#                 productivity  safety_compliant_business
# PROVINCE / LGU
# Quezon (MM)           0.7522                     1.2403
# Caloocan              0.1673                     0.8881
# Manila                0.5652                     0.6528
# Pasay                 2.0000                     1.2830
# Paranaque             0.5405                     0.3482

# %%
df_2023.loc["Quezon (MM)"]
# Out:
# active_establishments_in_the_locality                  1.7600
# cost_of_doing_business                                 1.4609
# cost_of_living                                         0.7925
# employment_generation                                  0.9248
# financial_deepening                                    1.3115
# local_economy_growth                                   0.5111
# local_economy_size                                     0.4807
# presence_of_business_and_professional_organizations    0.1880
# productivity                                           0.7522
# safety_compliant_business                              1.2403
# Name: Quezon (MM), dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(df):
    vif_data = pd.DataFrame()
    vif_data["Feature"] = df.columns
    vif_data["VIF"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    return vif_data

df_vif_2023 = calculate_vif(df_2023)
df_vif_2023
# Out:
#                                              Feature        VIF
# 0              active_establishments_in_the_locality  11.382224
# 1                             cost_of_doing_business  21.478783
# 2                                     cost_of_living  19.487497
# 3                              employment_generation   9.472916
# 4                                financial_deepening   9.180801
# 5                               local_economy_growth   2.002097
# 6                                 local_economy_size   7.477743
# 7  presence_of_business_and_professional_organiza...   2.733491
# 8                                       productivity  13.954281
# 9                          safety_compliant_business  10.562483

# %%
df_vif_2023[df_vif_2023["VIF"]<10]
# Out:
#                                              Feature       VIF
# 3                              employment_generation  9.472916
# 4                                financial_deepening  9.180801
# 5                               local_economy_growth  2.002097
# 6                                 local_economy_size  7.477743
# 7  presence_of_business_and_professional_organiza...  2.733491

# %%
#Check for other years:
df_vif = []
for year in ["2017", "2018", "2019", "2020", "2021", "2022", "2023"]:
    vif_per_year = calculate_vif(concat_year(year, df_names, dataframes))
    vif_per_year.rename(columns={"VIF": year}, inplace=True)
    df_vif.append(vif_per_year.set_index("Feature"))
df_vif = pd.concat(df_vif, axis=1)
df_vif
# Out:
#                                                          2017       2018  \
# Feature
# active_establishments_in_the_locality                5.375293   7.370544
# cost_of_doing_business                              38.299912  61.435719
# cost_of_living                                      41.569627  60.044832
# employment_generation                                4.413800   1.700540
# financial_deepening                                  5.006280  10.378706
# local_economy_growth                                 2.471867   5.855794
# local_economy_size                                   5.206583   2.899771
# presence_of_business_and_professional_organizat...   3.011245   5.837291
# productivity                                         2.355058   2.534077
# safety_compliant_business                            6.886711   4.977980
#
#                                                           2019       2020  \
# Feature
# active_establishments_in_the_locality                 7.764891   7.992509
# cost_of_doing_business                              115.178282   7.162587
# cost_of_living                                       93.988044   9.881378
# employment_generation                                 7.921876  14.074284
# financial_deepening                                   7.589250   8.968114
# local_economy_growth                                  5.430889   6.385751
# local_economy_size                                    7.973866  14.839503
# presence_of_business_and_professional_organizat...    2.364744   3.060768
# productivity                                         13.573734  37.326237
# safety_compliant_business                             9.221332   7.592217
#
#                                                          2021       2022  \
# Feature
# active_establishments_in_the_locality               12.487722  12.709310
# cost_of_doing_business                              13.510331  60.874452
# cost_of_living                                      17.295669  62.602530
# employment_generation                               11.482497   9.133051
# financial_deepening                                 13.358286   9.482077
# local_economy_growth                                 3.916462   2.701723
# local_economy_size                                  10.828888   7.430180
# presence_of_business_and_professional_organizat...   2.574057   1.231398
# productivity                                        25.859109  18.911147
# safety_compliant_business                            5.861845   3.309133
#
#                                                          2023
# Feature
# active_establishments_in_the_locality               11.382224
# cost_of_doing_business                              21.478783
# cost_of_living                                      19.487497
# employment_generation                                9.472916
# financial_deepening                                  9.180801
# local_economy_growth                                 2.002097
# local_economy_size                                   7.477743
# presence_of_business_and_professional_organizat...   2.733491
# productivity                                        13.954281
# safety_compliant_business                           10.562483

# %%
def highlight_greater_than_10(s):
    is_greater = s > 10
    return ['background-color: pink' if v else '' for v in is_greater]
df_vif.style.apply(highlight_greater_than_10)
# Out:
# <style type="text/css">
# #T_af1cb_row0_col4, #T_af1cb_row0_col5, #T_af1cb_row0_col6, #T_af1cb_row1_col0, #T_af1cb_row1_col1, #T_af1cb_row1_col2, #T_af1cb_row1_col4, #T_af1cb_row1_col5, #T_af1cb_row1_col6, #T_af1cb_row2_col0, #T_af1cb_row2_col1, #T_af1cb_row2_col2, #T_af1cb_row2_col4, #T_af1cb_row2_col5, #T_af1cb_row2_col6, #T_af1cb_row3_col3, #T_af1cb_row3_col4, #T_af1cb_row4_col1, #T_af1cb_row4_col4, #T_af1cb_row6_col3, #T_af1cb_row6_col4, #T_af1cb_row8_col2, #T_af1cb_row8_col3, #T_af1cb_row8_col4, #T_af1cb_row8_col5, #T_af1cb_row8_col6, #T_af1cb_row9_col6 {
#   background-color: pink;
# }
# </style>
# <table id="T_af1cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af1cb_level0_col0" class="col_heading level0 col0" >2017</th>
#       <th id="T_af1cb_level0_col1" class="col_heading level0 col1" >2018</th>
#       <th id="T_af1cb_level0_col2" class="col_heading level0 col2" >2019</th>
#       <th id="T_af1cb_level0_col3" class="col_heading level0 col3" >2020</th>
#       <th id="T_af1cb_level0_col4" class="col_heading level0 col4" >2021</th>
#       <th id="T_af1cb_level0_col5" class="col_heading level0 col5" >2022</th>
#       <th id="T_af1cb_level0_col6" class="col_heading level0 col6" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Feature</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af1cb_level0_row0" class="row_heading level0 row0" >active_establishments_in_the_locality</th>
#       <td id="T_af1cb_row0_col0" class="data row0 col0" >5.375293</td>
#       <td id="T_af1cb_row0_col1" class="data row0 col1" >7.370544</td>
#       <td id="T_af1cb_row0_col2" class="data row0 col2" >7.764891</td>
#       <td id="T_af1cb_row0_col3" class="data row0 col3" >7.992509</td>
#       <td id="T_af1cb_row0_col4" class="data row0 col4" >12.487722</td>
#       <td id="T_af1cb_row0_col5" class="data row0 col5" >12.709310</td>
#       <td id="T_af1cb_row0_col6" class="data row0 col6" >11.382224</td>
#     </tr>
#     <tr>
#       <th id="T_af1cb_level0_row1" class="row_heading level0 row1" >cost_of_doing_business</th>
#       <td id="T_af1cb_row1_col0" class="data row1 col0" >38.299912</td>
#       <td id="T_af1cb_row1_col1" class="data row1 col1" >61.435719</td>
#       <td id="T_af1cb_row1_col2" class="data row1 col2" >115.178282</td>
#       <td id="T_af1cb_row1_col3" class="data row1 col3" >7.162587</td>
#       <td id="T_af1cb_row1_col4" class="data row1 col4" >13.510331</td>
#       <td id="T_af1cb_row1_col5" class="data row1 col5" >60.874452</td>
#       <td id="T_af1cb_row1_col6" class="data row1 col6" >21.478783</td>
#     </tr>
#     <tr>
#       <th id="T_af1cb_level0_row2" class="row_heading level0 row2" >cost_of_living</th>
#       <td id="T_af1cb_row2_col0" class="data row2 col0" >41.569627</td>
#       <td id="T_af1cb_row2_col1" class="data row2 col1" >60.044832</td>
#       <td id="T_af1cb_row2_col2" class="data row2 col2" >93.988044</td>
#       <td id="T_af1cb_row2_col3" class="data row2 col3" >9.881378</td>
#       <td id="T_af1cb_row2_col4" class="data row2 col4" >17.295669</td>
#       <td id="T_af1cb_row2_col5" class="data row2 col5" >62.602530</td>
#       <td id="T_af1cb_row2_col6" class="data row2 col6" >19.487497</td>
#     </tr>
#     <tr>
#       <th id="T_af1cb_level0_row3" class="row_heading level0 row3" >employment_generation</th>
#       <td id="T_af1cb_row3_col0" class="data row3 col0" >4.413800</td>
#       <td id="T_af1cb_row3_col1" class="data row3 col1" >1.700540</td>
#       <td id="T_af1cb_row3_col2" class="data row3 col2" >7.921876</td>
#       <td id="T_af1cb_row3_col3" class="data row3 col3" >14.074284</td>
#       <td id="T_af1cb_row3_col4" class="data row3 col4" >11.482497</td>
#       <td id="T_af1cb_row3_col5" class="data row3 col5" >9.133051</td>
#       <td id="T_af1cb_row3_col6" class="data row3 col6" >9.472916</td>
#     </tr>
#     <tr>
#       <th id="T_af1cb_level0_row4" class="row_heading level0 row4" >financial_deepening</th>
#       <td id="T_af1cb_row4_col0" class="data row4 col0" >5.006280</td>
#       <td id="T_af1cb_row4_col1" class="data row4 col1" >10.378706</td>
#       <td id="T_af1cb_row4_col2" class="data row4 col2" >7.589250</td>
#       <td id="T_af1cb_row4_col3" class="data row4 col3" >8.968114</td>
#       <td id="T_af1cb_row4_col4" class="data row4 col4" >13.358286</td>
#       <td id="T_af1cb_row4_col5" class="data row4 col5" >9.482077</td>
#       <td id="T_af1cb_row4_col6" class="data row4 col6" >9.180801</td>
#     </tr>
#     <tr>
#       <th id="T_af1cb_level0_row5" class="row_heading level0 row5" >local_economy_growth</th>
#       <td id="T_af1cb_row5_col0" class="data row5 col0" >2.471867</td>
#       <td id="T_af1cb_row5_col1" class="data row5 col1" >5.855794</td>
#       <td id="T_af1cb_row5_col2" class="data row5 col2" >5.430889</td>
#       <td id="T_af1cb_row5_col3" class="data row5 col3" >6.385751</td>
#       <td id="T_af1cb_row5_col4" class="data row5 col4" >3.916462</td>
#       <td id="T_af1cb_row5_col5" class="data row5 col5" >2.701723</td>
#       <td id="T_af1cb_row5_col6" class="data row5 col6" >2.002097</td>
#     </tr>
#     <tr>
#       <th id="T_af1cb_level0_row6" class="row_heading level0 row6" >local_economy_size</th>
#       <td id="T_af1cb_row6_col0" class="data row6 col0" >5.206583</td>
#       <td id="T_af1cb_row6_col1" class="data row6 col1" >2.899771</td>
#       <td id="T_af1cb_row6_col2" class="data row6 col2" >7.973866</td>
#       <td id="T_af1cb_row6_col3" class="data row6 col3" >14.839503</td>
#       <td id="T_af1cb_row6_col4" class="data row6 col4" >10.828888</td>
#       <td id="T_af1cb_row6_col5" class="data row6 col5" >7.430180</td>
#       <td id="T_af1cb_row6_col6" class="data row6 col6" >7.477743</td>
#     </tr>
#     <tr>
#       <th id="T_af1cb_level0_row7" class="row_heading level0 row7" >presence_of_business_and_professional_organizations</th>
#       <td id="T_af1cb_row7_col0" class="data row7 col0" >3.011245</td>
#       <td id="T_af1cb_row7_col1" class="data row7 col1" >5.837291</td>
#       <td id="T_af1cb_row7_col2" class="data row7 col2" >2.364744</td>
#       <td id="T_af1cb_row7_col3" class="data row7 col3" >3.060768</td>
#       <td id="T_af1cb_row7_col4" class="data row7 col4" >2.574057</td>
#       <td id="T_af1cb_row7_col5" class="data row7 col5" >1.231398</td>
#       <td id="T_af1cb_row7_col6" class="data row7 col6" >2.733491</td>
#     </tr>
#     <tr>
#       <th id="T_af1cb_level0_row8" class="row_heading level0 row8" >productivity</th>
#       <td id="T_af1cb_row8_col0" class="data row8 col0" >2.355058</td>
#       <td id="T_af1cb_row8_col1" class="data row8 col1" >2.534077</td>
#       <td id="T_af1cb_row8_col2" class="data row8 col2" >13.573734</td>
#       <td id="T_af1cb_row8_col3" class="data row8 col3" >37.326237</td>
#       <td id="T_af1cb_row8_col4" class="data row8 col4" >25.859109</td>
#       <td id="T_af1cb_row8_col5" class="data row8 col5" >18.911147</td>
#       <td id="T_af1cb_row8_col6" class="data row8 col6" >13.954281</td>
#     </tr>
#     <tr>
#       <th id="T_af1cb_level0_row9" class="row_heading level0 row9" >safety_compliant_business</th>
#       <td id="T_af1cb_row9_col0" class="data row9 col0" >6.886711</td>
#       <td id="T_af1cb_row9_col1" class="data row9 col1" >4.977980</td>
#       <td id="T_af1cb_row9_col2" class="data row9 col2" >9.221332</td>
#       <td id="T_af1cb_row9_col3" class="data row9 col3" >7.592217</td>
#       <td id="T_af1cb_row9_col4" class="data row9 col4" >5.861845</td>
#       <td id="T_af1cb_row9_col5" class="data row9 col5" >3.309133</td>
#       <td id="T_af1cb_row9_col6" class="data row9 col6" >10.562483</td>
#     </tr>
#   </tbody>
# </table>

# %%
# At least two out of 2021 - 2023
cmci_shortlist = list(df_vif.index[np.r_[3:8, 9]])
cmci_2023 = df_2023[cmci_shortlist]
# cmci_2023.to_csv("CMCI_2023_Shortlist.csv", encoding="UTF-8-sig")
cmci_2023.head()
# Out:
#                 employment_generation  financial_deepening  \
# PROVINCE / LGU
# Quezon (MM)                    0.9248               1.3115
# Caloocan                       0.1654               0.4734
# Manila                         0.4600               1.1539
# Pasay                          2.0000               0.5909
# Paranaque                      0.7071               0.3316
#
#                 local_economy_growth  local_economy_size  \
# PROVINCE / LGU
# Quezon (MM)                   0.5111              0.4807
# Caloocan                      0.3167              0.0555
# Manila                        0.3905              0.3591
# Pasay                         0.2022              2.0000
# Paranaque                     0.2952              0.3623
#
#                 presence_of_business_and_professional_organizations  \
# PROVINCE / LGU
# Quezon (MM)                                                0.1880
# Caloocan                                                   0.0567
# Manila                                                     0.3590
# Pasay                                                      0.1095
# Paranaque                                                  0.0081
#
#                 safety_compliant_business
# PROVINCE / LGU
# Quezon (MM)                        1.2403
# Caloocan                           0.8881
# Manila                             0.6528
# Pasay                              1.2830
# Paranaque                          0.3482
